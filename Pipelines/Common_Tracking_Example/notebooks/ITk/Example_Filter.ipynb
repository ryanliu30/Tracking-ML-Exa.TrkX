# %% [markdown]
# # Example of Filtering Embedded Pairs

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# System imports
import os
import sys
import yaml

# External imports
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.decomposition import PCA
from sklearn.metrics import auc
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from pytorch_lightning.loggers import TensorBoardLogger, WandbLogger
from pytorch_lightning import Trainer

sys.path.append('../..')
device = "cuda" if torch.cuda.is_available() else "cpu"

from LightningModules.Filter.Models.vanilla_filter import VanillaFilter
from LightningModules.Filter.Models.pyramid_filter import PyramidFilter

# %% [markdown]
# ## Pytorch Lightning Model

# %% [markdown]
# ### Construct PyLightning model

# %% [markdown]
# An ML model typically has many knobs to turn, as well as locations of data, some training preferences, and so on. For convenience, let's put all of these parameters into a YAML file and load it.

# %%
with open("example_filter.yaml") as f:
        hparams = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# We plug these parameters into a constructor of the `LayerlessEmbedding` Lightning Module. This doesn't **do** anything yet - merely creates the object.

# %%
model = PyramidFilter(hparams)

# %% [markdown]
# ## The Dataset

# %%
model.setup(stage="fit")

# %% [markdown]
# Just as a sanity check, let's look directly at the geometry of the data, as well as some distributions. This is just to make sure that, e.g. it's normalised in some reasonable way (that is, it doesn't vary from -1000 to +1000 or some large numbers, but that it is distributed close to +1 and -1 - this makes training much more effective!), and there aren't weird outliers (this also damages training!).

# %%
trainset = model.trainset

# %%
example_data = trainset[0]
r, phi, z = example_data.x.T

# %%
x, y = r*np.cos(phi*np.pi)*1000, r*np.sin(phi*np.pi)*1000
z = z*1000

# %%
fig, axs = plt.subplots(1, 2, figsize=(22,10))
axs[0].scatter(z, x, s=1)
axs[1].scatter(x, y, s=1)
axs[0].set_title("Longitudinal Spacepoint Distribution", fontsize=24), axs[0].set_xlabel("z direction (mm)", fontsize=18), axs[0].set_ylabel("x direction (mm)", fontsize=18)
axs[1].set_title("Down-beampipe Spacepoint Distribution", fontsize=24), axs[1].set_xlabel("x direction (mm)", fontsize=18), axs[1].set_ylabel("y direction (mm)", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Down-beampipe Spacepoint Distribution'),
#  Text(0.5, 0, 'x direction (mm)'),
#  Text(0, 0.5, 'y direction (mm)'))

# %%
plt.figure(figsize=(12,8))
sns.histplot(example_data.pt[example_data.pt == example_data.pt], binwidth=200, binrange=[0, 5000])
plt.title("Distribution of Momentum", fontsize=24), plt.xlabel("pT (GeV)", fontsize=18), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Momentum'),
#  Text(0.5, 0, 'pT (GeV)'),
#  Text(0, 0.5, 'Count'))

# %%
plt.figure(figsize=(12,8))
sns.histplot(example_data.pt[example_data.modulewise_true_edges[0]], binrange=[0, 5000])
plt.title("Distribution of Momentum", fontsize=24), plt.xlabel("pT (GeV)", fontsize=18), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Momentum'),
#  Text(0.5, 0, 'pT (GeV)'),
#  Text(0, 0.5, 'Count'))

# %% [markdown]
# Observe the hard cut-off below 1GeV - this is because we are ignoring lower energy hits to keep things easy for now. But we should include them again once we are happy with our ML architecture!

# %%
particle_num, particle_counts = np.unique(example_data.pid.numpy(), return_counts = True)

# %%
plt.figure(figsize=(12,8))
sns.histplot(particle_counts[:-1], binwidth=1)
plt.title("Distribution of Hits per Particle", fontsize=24), plt.xlabel("Hits", fontsize=18), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Hits per Particle'),
#  Text(0.5, 0, 'Hits'),
#  Text(0, 0.5, 'Count'))

# %% [markdown]
# This gives an idea about how long each particle track is. We can see that most particle tracks leave > 10 hits, which will be useful for our graph neural networks down the track. In general, shorter tracks are harder to detect, and less useful for doing meaningful physics.

# %%
cell_features = [
            "norm_x",
            "norm_y",
            "barrel_endcap",
            "layer_disk",
            "eta_module",
            "phi_module",
            "eta_angle_1",
            "phi_angle_1",
            "eta_angle_2",
            "phi_angle_2",
            "pixel"
        ]

# %%
example_data.cell_data
# Out:
# tensor([[ 0.0000,  0.0000, -2.0000,  ..., -1.0000, -1.0000,  1.0000],
#         [ 0.0000,  0.0000, -2.0000,  ..., -1.0000, -1.0000,  1.0000],
#         [ 0.0000,  0.0000, -2.0000,  ..., -1.0000, -1.0000,  1.0000],
#         ...,
#         [ 0.0000,  0.0000,  2.0000,  ...,  1.3246,  0.0064,  0.0000],
#         [ 0.0000,  0.0000,  2.0000,  ...,  1.3239,  0.0059,  0.0000],
#         [ 0.0000,  0.0000,  2.0000,  ...,  1.3246,  0.0064,  0.0000]])

# %%
for i, feature in enumerate(cell_features):
    plt.figure()
    sns.histplot(example_data.cell_data[:, i].numpy()).set_title(feature)

# %% [markdown]
# ## Metric Learning

# %% [markdown]
# ### Train filter

# %% [markdown]
# Finally! Let's train! We instantiate a `Trainer` class that knows things like which hardware to work with, how long to train for, and a **bunch** of default options that we ignore here. Check out the Trainer class docs in Pytorch Lightning. Suffice it to say that it clears away much repetitive boilerplate in training code.

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    monitor='eff',
    mode="max",
    save_top_k=2,
    save_last=True)

# %%
# %%time
# logger = WandbLogger(project="ITk_0GeV_Filter", group="InitialTest")
trainer = Trainer(gpus=1, max_epochs=20, num_sanity_val_steps=0, logger=None, callbacks=[checkpoint_callback])
trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type       | Params
# --------------------------------------------
# 0 | input_layer  | Linear     | 23.6 K
# 1 | layers       | ModuleList | 656 K
# 2 | output_layer | Linear     | 257
# 3 | act          | Tanh       | 0
# --------------------------------------------
# 679 K     Trainable params
# 0         Non-trainable params
# 679 K     Total params
# 2.720     Total estimated model params size (MB)
# /global/homes/r/ryanliu/.conda/envs/gnn/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:116: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 256 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /global/homes/r/ryanliu/.conda/envs/gnn/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:116: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 256 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00,  1.13it/s, loss=0.983]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it, loss=0.983]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, loss=0.983]
# /global/homes/r/ryanliu/.conda/envs/gnn/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:59: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00,  1.19it/s, loss=0.979]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it, loss=0.979]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00,  1.09it/s, loss=0.973]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it, loss=0.973]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00,  1.19it/s, loss=0.969]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it, loss=0.969]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00,  1.22it/s, loss=0.967]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 2/2 [00:02<00:00,  1.26s/it, loss=0.967]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00,  1.29it/s, loss=0.966]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 2/2 [00:02<00:00,  1.21s/it, loss=0.966]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00,  1.08it/s, loss=0.964]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 2/2 [00:02<00:00,  1.17s/it, loss=0.964]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00,  1.03it/s, loss=0.961]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it, loss=0.961]
# Epoch 8:  50%|█████     | 1/2 [00:01<00:01,  1.18s/it, loss=0.958]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████| 2/2 [00:02<00:00,  1.43s/it, loss=0.958]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00,  1.17it/s, loss=0.954]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it, loss=0.954]
# Epoch 10:  50%|█████     | 1/2 [00:00<00:00,  1.24it/s, loss=0.951]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it, loss=0.951]
# Epoch 11:  50%|█████     | 1/2 [00:00<00:00,  1.27it/s, loss=0.949]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it, loss=0.949]
# Epoch 12:  50%|█████     | 1/2 [00:00<00:00,  1.22it/s, loss=0.948]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|██████████| 2/2 [00:02<00:00,  1.25s/it, loss=0.948]
# Epoch 13:  50%|█████     | 1/2 [00:00<00:00,  1.28it/s, loss=0.947]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it, loss=0.947]
# Epoch 14:  50%|█████     | 1/2 [00:00<00:00,  1.22it/s, loss=0.945]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it, loss=0.945]
# Epoch 15:  50%|█████     | 1/2 [00:00<00:00,  1.26it/s, loss=0.944]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it, loss=0.944]
# Epoch 16:  50%|█████     | 1/2 [00:00<00:00,  1.17it/s, loss=0.943]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it, loss=0.943]
# Epoch 17:  50%|█████     | 1/2 [00:00<00:00,  1.30it/s, loss=0.942]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|██████████| 2/2 [00:02<00:00,  1.25s/it, loss=0.942]
# Epoch 18:  50%|█████     | 1/2 [00:00<00:00,  1.20it/s, loss=0.942]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|██████████| 2/2 [00:02<00:00,  1.25s/it, loss=0.942]
# Epoch 19:  50%|█████     | 1/2 [00:00<00:00,  1.33it/s, loss=0.941]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it, loss=0.941]
# Epoch 19: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it, loss=0.941]
# CPU times: user 38.9 s, sys: 7.37 s, total: 46.3 s
# Wall time: 56 s

# %% [markdown]
# ### Test filter

# %% [markdown]
# A Pytorch Lightning Trainer has two main methods: `fit` and `test`. They represent the two main steps of any ML engingeering or research: Train a model, then make sure it can infer accurately on test (i.e. **hidden**) data.

# %% [markdown]
# Note that `ckpt_path` just tells the trainer to use the latest "checkpoint" of the model, rather than *best* checkpoint. A checkpoint is a saved version of the model, a snapshot at a particular stage of the training process. Pytorch Lightning automatically saves a checkpoint of your model in case something crashes and we need to resume.

# %%
test_results = trainer.test(ckpt_path=None)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.9709646701812744,
#  'pur': 0.055771585553884506,
#  'val_loss': 0.9984596371650696}
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Performance

# %%
checkpoint_path = "/global/cscratch1/sd/danieltm/ExaTrkX/itk_lightning_checkpoints/ITk_1GeV_Filter/avcwv9al/checkpoints/last.ckpt"
checkpoint = torch.load(checkpoint_path)

model = PyramidFilter.load_from_checkpoint(checkpoint_path).to(device)

# %%
model.eval();

# %%
model.hparams["datatype_split"] = [10, 1, 10]
# model.setup(stage="fit")

# %%
batch = model.testset[1]

# %%
with torch.no_grad():
    test_results = model.test_step(model.testset[1].to(device), 0)
# Out:
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/torch/nn/functional.py:1805: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
cut = 0.2

# %%
test_results["preds"].shape
# Out:
# torch.Size([1758556])

# %%
(test_results["preds"] > cut).sum()
# Out:
# tensor(958606, device='cuda:0')

# %%
(test_results["trues"] & (test_results["preds"] > cut)).sum()
# Out:
# tensor(11892, device='cuda:0')

# %%
(test_results["trues"] & (test_results["preds"] > cut)).sum() / (test_results["preds"] > cut).sum()
# Out:
# tensor(0.0124, device='cuda:0')

# %%
(test_results["trues"] & (test_results["preds"] > cut)).sum() / test_results["trues"].int().sum()
# Out:
# tensor(0.9881, device='cuda:0')

# %%
test_results
# Out:
# {'preds': tensor([0.0146, 0.0146, 0.0145,  ..., 0.0043, 0.0042, 0.0042], device='cuda:0'),
#  'trues': tensor([False, False, False,  ..., False, False, False], device='cuda:0'),
#  'loss': tensor(3.7315, device='cuda:0')}

# %%
subset_mask = np.isin(batch.edge_index.cpu(), batch.modulewise_true_edges.unique().cpu()).any(0)

# %%
test_results["preds"].cpu()[::100].shape
# Out:
# torch.Size([17586])

# %%
true_preds.shape
# Out:
# torch.Size([12035])

# %%
false_preds.shape
# Out:
# torch.Size([1746521])

# %%
true_preds = test_results["preds"][test_results["trues"].cpu() & subset_mask]
false_preds = test_results["preds"][~test_results["trues"].cpu() & subset_mask]
# Out:
# /global/homes/d/danieltm/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
#   """Entry point for launching an IPython kernel.
# /global/homes/d/danieltm/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)

# %% [markdown]
# ## Build Edges

# %%
import copy
class FilterInferenceBuilder:
    def __init__(self, model, output_dir, overwrite=False):
        self.output_dir = output_dir
        self.model = model
        self.overwrite = overwrite

        # Prep the directory to produce inference data to
        self.datatypes = ["train", "val", "test"]
        os.makedirs(self.output_dir, exist_ok=True)
        [
            os.makedirs(os.path.join(self.output_dir, datatype), exist_ok=True)
            for datatype in self.datatypes
        ]
        
        # Get [train, val, test] lists of files
        self.dataset_list = []
        for dataname in model.hparams["datatype_names"]:
            dataset = os.listdir(os.path.join(model.hparams["input_dir"], dataname))
            dataset = sorted([os.path.join(model.hparams["input_dir"], dataname, event) for event in dataset])
            self.dataset_list.append(dataset)
        

    def build(self):
        print("Training finished, running inference to build graphs...")

        # By default, the set of examples propagated through the pipeline will be train+val+test set
        datasets = {
            "train": self.dataset_list[0],
            "val": self.dataset_list[1],
            "test": self.dataset_list[2],
        }
        total_length = sum([len(dataset) for dataset in datasets.values()])
        batch_incr = 0
        self.model.eval()
        with torch.no_grad():
            for set_idx, (datatype, dataset) in enumerate(datasets.items()):
                for event_idx, event_file in enumerate(dataset):
                    percent = (batch_incr / total_length) * 100
                    sys.stdout.flush()
                    sys.stdout.write(f"{percent:.01f}% inference complete \r")
                    batch = torch.load(event_file).to(device)
                    if (
                        not os.path.exists(
                            os.path.join(
                                self.output_dir, datatype, batch.event_file[-4:]
                            )
                        )
                    ) or self.overwrite:
                        batch_to_save = copy.deepcopy(batch)
                        batch_to_save = batch_to_save.to(
                            self.model.device
                        )  # Is this step necessary??
                        self.construct_downstream(batch_to_save, datatype)

                    batch_incr += 1

    def construct_downstream(self, batch, datatype):

        
        emb = (
            None if (self.model.hparams["emb_channels"] == 0) else batch.embedding
        )  # Does this work??

        cut_list = []
        for j in range(self.model.hparams["n_chunks"]):
            subset_ind = torch.chunk(torch.arange(batch.edge_index.shape[1]), self.model.hparams["n_chunks"])[
                j
            ]
            output = (
                self.model(
                    torch.cat([batch.cell_data[:, :self.model.hparams["cell_channels"]], batch.x], axis=-1),
                    batch.edge_index[:, subset_ind],
                    emb,
                ).squeeze()
                if ("ci" in self.model.hparams["regime"])
                else self.model(batch.x, batch.edge_index[:, subset_ind], emb).squeeze()
            )
            cut = torch.sigmoid(output) > self.model.hparams["filter_cut"]
            cut_list.append(cut)

        cut_list = torch.cat(cut_list)

        if "pid" not in self.model.hparams["regime"]:
            batch.y = batch.y[cut_list]

            print(batch.y.shape)
            print(batch.y.sum())
            
        y_pid = batch.pid[batch.edge_index[0]] == batch.pid[batch.edge_index[1]]
        batch.y_pid = y_pid[cut_list]
        batch.edge_index = batch.edge_index[:, cut_list]
        if "weighting" in self.model.hparams["regime"]:
            batch.weights = batch.weights[cut_list]

        self.save_downstream(batch, datatype)
        
        

    def save_downstream(self, batch, datatype):

        with open(
            os.path.join(self.output_dir, datatype, batch.event_file[-4:]), "wb"
        ) as pickle_file:
            torch.save(batch, pickle_file)

# %%
output_dir = "/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff"
model.hparams["train_split"] = [10, 1, 1]
model.hparams["filter_cut"] = 0.15

# %%
edge_builder = FilterInferenceBuilder(model, output_dir, overwrite=True)
    
edge_builder.build()
# Out:
# Training finished, running inference to build graphs...
# torch.Size([732541])ete
# tensor(3610, device='cuda:0')
# torch.Size([757733])ete
# tensor(3275, device='cuda:0')
# torch.Size([400687])ete
# tensor(2412, device='cuda:0')
# torch.Size([505722])ete
# tensor(2447, device='cuda:0')
# torch.Size([813216])ete
# tensor(3576, device='cuda:0')
# torch.Size([830793])ete
# tensor(3759, device='cuda:0')
# torch.Size([519213])ete
# tensor(2514, device='cuda:0')
# torch.Size([726540])ete
# tensor(3431, device='cuda:0')
# torch.Size([880201])ete
# tensor(3885, device='cuda:0')
# torch.Size([748403])ete
# tensor(3545, device='cuda:0')
# torch.Size([736408])ete
# tensor(3227, device='cuda:0')
# torch.Size([681831])ete
# tensor(3000, device='cuda:0')
# torch.Size([600417])ete
# tensor(3093, device='cuda:0')
# torch.Size([887521])ete
# tensor(3707, device='cuda:0')
# torch.Size([655031])ete
# tensor(3476, device='cuda:0')
# torch.Size([841009])ete
# tensor(3751, device='cuda:0')
# torch.Size([677400])ete
# tensor(3179, device='cuda:0')
# torch.Size([593784])ete
# tensor(3081, device='cuda:0')
# torch.Size([458054])ete
# tensor(2306, device='cuda:0')
# torch.Size([581688])ete
# tensor(2987, device='cuda:0')
# torch.Size([647167])ete
# tensor(2972, device='cuda:0')
# torch.Size([430298])ete
# tensor(2660, device='cuda:0')
# torch.Size([392573])ete
# tensor(2409, device='cuda:0')
# torch.Size([501203])ete
# tensor(2880, device='cuda:0')
# torch.Size([466446])ete
# tensor(2702, device='cuda:0')
# torch.Size([442470])ete
# tensor(2451, device='cuda:0')
# torch.Size([396043])ete
# tensor(2419, device='cuda:0')
# torch.Size([678008])ete
# tensor(3219, device='cuda:0')
# torch.Size([699413])ete
# tensor(3425, device='cuda:0')
# torch.Size([739652])ete
# tensor(3836, device='cuda:0')
# torch.Size([620187])ete
# tensor(3314, device='cuda:0')
# torch.Size([471505])ete
# tensor(2842, device='cuda:0')
# torch.Size([352734])ete
# tensor(2326, device='cuda:0')
# torch.Size([540856])ete
# tensor(3000, device='cuda:0')
# torch.Size([389070])ete
# tensor(2191, device='cuda:0')
# torch.Size([579152])ete
# tensor(2712, device='cuda:0')
# torch.Size([553826])ete
# tensor(3174, device='cuda:0')
# torch.Size([476428])ete
# tensor(2546, device='cuda:0')
# torch.Size([630296])ete
# tensor(3014, device='cuda:0')
# torch.Size([649003])ete
# tensor(3587, device='cuda:0')
# torch.Size([663057])ete
# tensor(3790, device='cuda:0')
# torch.Size([813778])ete
# tensor(3955, device='cuda:0')
# torch.Size([512228])ete
# tensor(2787, device='cuda:0')
# torch.Size([550352])ete
# tensor(2745, device='cuda:0')
# torch.Size([558470])ete
# tensor(3206, device='cuda:0')
# torch.Size([522246])ete
# tensor(3047, device='cuda:0')
# torch.Size([535636])ete
# tensor(2807, device='cuda:0')
# torch.Size([747581])ete
# tensor(3599, device='cuda:0')
# torch.Size([518994])ete
# tensor(2660, device='cuda:0')
# torch.Size([480939])ete
# tensor(2403, device='cuda:0')
# torch.Size([884351])ete
# tensor(3490, device='cuda:0')
# torch.Size([658501])ete
# tensor(3445, device='cuda:0')
# torch.Size([616444])ete
# tensor(3252, device='cuda:0')
# torch.Size([667910])ete
# tensor(3363, device='cuda:0')
# torch.Size([801554])ete
# tensor(3682, device='cuda:0')
# torch.Size([509774])ete
# tensor(2824, device='cuda:0')
# torch.Size([591841])ete
# tensor(3442, device='cuda:0')
# torch.Size([519138])ete
# tensor(2820, device='cuda:0')
# torch.Size([800423])ete
# tensor(3325, device='cuda:0')
# torch.Size([627484])ete
# tensor(2977, device='cuda:0')
# torch.Size([548550])ete
# tensor(2865, device='cuda:0')
# torch.Size([872207])ete
# tensor(3778, device='cuda:0')
# torch.Size([863656])ete
# tensor(3907, device='cuda:0')
# torch.Size([624205])ete
# tensor(3171, device='cuda:0')
# torch.Size([613985])ete
# tensor(3017, device='cuda:0')
# torch.Size([737162])ete
# tensor(3218, device='cuda:0')
# torch.Size([721028])ete
# tensor(3444, device='cuda:0')
# torch.Size([666844])ete
# tensor(3245, device='cuda:0')
# torch.Size([874289])ete
# tensor(3835, device='cuda:0')
# torch.Size([676507])ete
# tensor(3316, device='cuda:0')
# torch.Size([600790])ete
# tensor(2805, device='cuda:0')
# torch.Size([536319])ete
# tensor(2624, device='cuda:0')
# torch.Size([587770])ete
# tensor(2805, device='cuda:0')
# torch.Size([556123])ete
# tensor(3034, device='cuda:0')
# torch.Size([512426])ete
# tensor(2766, device='cuda:0')
# torch.Size([915993])ete
# tensor(3975, device='cuda:0')
# torch.Size([621309])ete
# tensor(3339, device='cuda:0')
# torch.Size([531175])ete
# tensor(3304, device='cuda:0')
# torch.Size([936082])ete
# tensor(4160, device='cuda:0')
# torch.Size([460181])ete
# tensor(2758, device='cuda:0')
# torch.Size([558779])ete
# tensor(2916, device='cuda:0')
# torch.Size([630549])ete
# tensor(3106, device='cuda:0')
# torch.Size([535972])ete
# tensor(2835, device='cuda:0')
# torch.Size([574854])ete
# tensor(3205, device='cuda:0')
# torch.Size([777568])ete
# tensor(3713, device='cuda:0')
# torch.Size([627520])ete
# tensor(3346, device='cuda:0')
# torch.Size([468902])ete
# tensor(2667, device='cuda:0')
# torch.Size([555926])ete
# tensor(3036, device='cuda:0')
# torch.Size([422596])ete
# tensor(2613, device='cuda:0')
# torch.Size([629491])ete
# tensor(3099, device='cuda:0')
# torch.Size([489249])ete
# tensor(2703, device='cuda:0')
# torch.Size([761215])ete
# tensor(3718, device='cuda:0')
# torch.Size([781559])ete
# tensor(3842, device='cuda:0')
# torch.Size([753385])ete
# tensor(3381, device='cuda:0')
# torch.Size([455188])ete
# tensor(2612, device='cuda:0')
# torch.Size([870850])ete
# tensor(3991, device='cuda:0')
# torch.Size([867326])ete
# tensor(4089, device='cuda:0')
# torch.Size([755932])ete
# tensor(3320, device='cuda:0')
# torch.Size([513507])ete
# tensor(2838, device='cuda:0')
# torch.Size([364761])ete
# tensor(2337, device='cuda:0')
# torch.Size([591890])ete
# tensor(3021, device='cuda:0')
# torch.Size([892532])ete
# tensor(4152, device='cuda:0')
# torch.Size([648470])ete
# tensor(3501, device='cuda:0')
# torch.Size([570580])ete
# tensor(3124, device='cuda:0')
# torch.Size([476793])ete
# tensor(2692, device='cuda:0')
# torch.Size([516414])ete
# tensor(2907, device='cuda:0')
# torch.Size([415134])ete
# tensor(2562, device='cuda:0')
# torch.Size([589568])ete
# tensor(3075, device='cuda:0')
# torch.Size([571368])ete
# tensor(2878, device='cuda:0')
# torch.Size([572718])ete
# tensor(2921, device='cuda:0')
# torch.Size([502053])ete
# tensor(2708, device='cuda:0')
# torch.Size([578223])ete
# tensor(2842, device='cuda:0')
# torch.Size([513678])ete
# tensor(3040, device='cuda:0')
# torch.Size([700511])ete
# tensor(3428, device='cuda:0')
# torch.Size([870991])ete
# tensor(3793, device='cuda:0')
# torch.Size([590934])ete
# tensor(3126, device='cuda:0')
# torch.Size([650979])ete
# tensor(3287, device='cuda:0')
# torch.Size([498317])ete
# tensor(2845, device='cuda:0')
# torch.Size([575723])ete
# tensor(2885, device='cuda:0')
# torch.Size([578071])ete
# tensor(2916, device='cuda:0')
# torch.Size([1078570])te
# tensor(4367, device='cuda:0')
# torch.Size([550315])ete
# tensor(2965, device='cuda:0')
# torch.Size([766321])ete
# tensor(3822, device='cuda:0')
# torch.Size([644871])ete
# tensor(3141, device='cuda:0')
# torch.Size([641408])ete
# tensor(2844, device='cuda:0')
# torch.Size([992301])ete
# tensor(3811, device='cuda:0')
# torch.Size([925331])ete
# tensor(3630, device='cuda:0')
# torch.Size([640322])ete
# tensor(2921, device='cuda:0')
# torch.Size([669518])ete
# tensor(3170, device='cuda:0')
# torch.Size([571012])ete
# tensor(2934, device='cuda:0')
# torch.Size([666627])ete
# tensor(3312, device='cuda:0')
# torch.Size([816209])ete
# tensor(3345, device='cuda:0')
# torch.Size([825552])ete
# tensor(3664, device='cuda:0')
# torch.Size([721264])ete
# tensor(3383, device='cuda:0')
# torch.Size([540841])ete
# tensor(2980, device='cuda:0')
# torch.Size([782731])ete
# tensor(3369, device='cuda:0')
# torch.Size([668456])ete
# tensor(3262, device='cuda:0')
# torch.Size([757294])ete
# tensor(3482, device='cuda:0')
# torch.Size([607357])ete
# tensor(3065, device='cuda:0')
# torch.Size([485974])ete
# tensor(2762, device='cuda:0')
# torch.Size([739294])ete
# tensor(3419, device='cuda:0')
# torch.Size([635377])ete
# tensor(3218, device='cuda:0')
# torch.Size([715850])ete
# tensor(3446, device='cuda:0')
# torch.Size([556892])ete
# tensor(2798, device='cuda:0')
# torch.Size([530815])ete
# tensor(3145, device='cuda:0')
# torch.Size([507738])ete
# tensor(2823, device='cuda:0')
# torch.Size([519986])ete
# tensor(2852, device='cuda:0')
# torch.Size([435903])ete
# tensor(2617, device='cuda:0')
# torch.Size([858475])ete
# tensor(3827, device='cuda:0')
# torch.Size([661814])ete
# tensor(3275, device='cuda:0')
# torch.Size([470952])ete
# tensor(2573, device='cuda:0')
# torch.Size([576534])ete
# tensor(3138, device='cuda:0')
# torch.Size([538588])ete
# tensor(2768, device='cuda:0')
# torch.Size([472280])ete
# tensor(2611, device='cuda:0')
# torch.Size([617321])ete
# tensor(3219, device='cuda:0')
# torch.Size([443607])ete
# tensor(2886, device='cuda:0')
# torch.Size([480611])ete
# tensor(2752, device='cuda:0')
# torch.Size([448422])ete
# tensor(2628, device='cuda:0')
# torch.Size([521197])ete
# tensor(2955, device='cuda:0')
# torch.Size([533015])ete
# tensor(3023, device='cuda:0')
# torch.Size([481952])ete
# tensor(2683, device='cuda:0')
# torch.Size([484327])ete
# tensor(2852, device='cuda:0')
# torch.Size([495777])ete
# tensor(2772, device='cuda:0')
# torch.Size([478414])ete
# tensor(2597, device='cuda:0')
# torch.Size([687256])ete
# tensor(3683, device='cuda:0')
# torch.Size([475751])ete
# tensor(3126, device='cuda:0')
# torch.Size([885554])ete
# tensor(4024, device='cuda:0')
# torch.Size([417582])ete
# tensor(2516, device='cuda:0')
# torch.Size([476794])ete
# tensor(2557, device='cuda:0')
# torch.Size([567404])ete
# tensor(3024, device='cuda:0')
# torch.Size([860081])ete
# tensor(3792, device='cuda:0')
# torch.Size([415325])ete
# tensor(2534, device='cuda:0')
# torch.Size([711961])ete
# tensor(3218, device='cuda:0')
# torch.Size([760944])ete
# tensor(3521, device='cuda:0')
# torch.Size([703470])ete
# tensor(3475, device='cuda:0')
# torch.Size([641593])ete
# tensor(3066, device='cuda:0')
# torch.Size([539359])ete
# tensor(2645, device='cuda:0')
# torch.Size([628975])ete
# tensor(3091, device='cuda:0')
# torch.Size([654954])ete
# tensor(2958, device='cuda:0')
# torch.Size([550663])ete
# tensor(2833, device='cuda:0')
# torch.Size([776338])ete
# tensor(3404, device='cuda:0')
# torch.Size([627465])ete
# tensor(3355, device='cuda:0')
# torch.Size([659944])ete
# tensor(2911, device='cuda:0')
# torch.Size([645889])ete
# tensor(2918, device='cuda:0')
# torch.Size([568664])ete
# tensor(2820, device='cuda:0')
# torch.Size([587180])ete
# tensor(3217, device='cuda:0')
# torch.Size([701047])ete
# tensor(3176, device='cuda:0')
# torch.Size([729441])ete
# tensor(3200, device='cuda:0')
# torch.Size([497426])ete
# tensor(2595, device='cuda:0')
# torch.Size([1159874])te
# tensor(4382, device='cuda:0')
# torch.Size([528908])ete
# tensor(2854, device='cuda:0')
# torch.Size([626130])ete
# tensor(3087, device='cuda:0')
# torch.Size([704100])ete
# tensor(3349, device='cuda:0')
# torch.Size([536390])ete
# tensor(2699, device='cuda:0')
# torch.Size([526118])ete
# tensor(2788, device='cuda:0')
# torch.Size([623694])ete
# tensor(3284, device='cuda:0')
# torch.Size([711401])ete
# tensor(3518, device='cuda:0')
# torch.Size([720777])ete
# tensor(3390, device='cuda:0')
# torch.Size([445345])ete
# tensor(2604, device='cuda:0')
# torch.Size([625106])ete
# tensor(3125, device='cuda:0')
# torch.Size([637115])ete
# tensor(3349, device='cuda:0')
# torch.Size([581920])ete
# tensor(3105, device='cuda:0')
# torch.Size([582484])ete
# tensor(3008, device='cuda:0')
# torch.Size([752160])lete
# tensor(3604, device='cuda:0')
# torch.Size([549833])lete
# tensor(2904, device='cuda:0')
# torch.Size([845069])lete
# tensor(3573, device='cuda:0')
# torch.Size([778489])lete
# tensor(3737, device='cuda:0')
# torch.Size([682548])lete
# tensor(3389, device='cuda:0')
# torch.Size([516649])lete
# tensor(3164, device='cuda:0')
# torch.Size([447431])lete
# tensor(2770, device='cuda:0')
# torch.Size([456793])lete
# tensor(2710, device='cuda:0')
# torch.Size([580920])lete
# tensor(3274, device='cuda:0')
# torch.Size([606921])lete
# tensor(3265, device='cuda:0')
# torch.Size([677233])lete
# tensor(3261, device='cuda:0')
# torch.Size([442641])lete
# tensor(2658, device='cuda:0')
# torch.Size([594614])lete
# tensor(2983, device='cuda:0')
# torch.Size([585567])lete
# tensor(3322, device='cuda:0')
# torch.Size([485179])lete
# tensor(2576, device='cuda:0')
# torch.Size([423008])lete
# tensor(2542, device='cuda:0')
# torch.Size([351755])lete
# tensor(2316, device='cuda:0')
# torch.Size([555119])lete
# tensor(3134, device='cuda:0')
# torch.Size([352702])lete
# tensor(2350, device='cuda:0')
# torch.Size([622542])lete
# tensor(3322, device='cuda:0')
# torch.Size([453447])lete
# tensor(2452, device='cuda:0')
# torch.Size([477226])lete
# tensor(2691, device='cuda:0')
# torch.Size([460091])lete
# tensor(2701, device='cuda:0')
# torch.Size([625514])lete
# tensor(3077, device='cuda:0')
# torch.Size([609785])lete
# tensor(3261, device='cuda:0')
# torch.Size([497298])lete
# tensor(2727, device='cuda:0')
# torch.Size([519516])lete
# tensor(2854, device='cuda:0')
# torch.Size([480493])lete
# tensor(2809, device='cuda:0')
# torch.Size([424485])lete
# tensor(2464, device='cuda:0')
# torch.Size([505607])lete
# tensor(2916, device='cuda:0')
# torch.Size([687948])lete
# tensor(3708, device='cuda:0')
# torch.Size([481708])lete
# tensor(2978, device='cuda:0')
# torch.Size([731633])lete
# tensor(3850, device='cuda:0')
# torch.Size([808242])lete
# tensor(3865, device='cuda:0')
# torch.Size([568219])lete
# tensor(3473, device='cuda:0')
# torch.Size([713069])lete
# tensor(3243, device='cuda:0')
# torch.Size([637589])lete
# tensor(3182, device='cuda:0')
# torch.Size([921464])lete
# tensor(3982, device='cuda:0')
# torch.Size([683982])lete
# tensor(3208, device='cuda:0')
# torch.Size([706110])lete
# tensor(3487, device='cuda:0')
# torch.Size([786335])lete
# tensor(3531, device='cuda:0')
# torch.Size([638633])lete
# tensor(3034, device='cuda:0')
# torch.Size([903248])lete
# tensor(4116, device='cuda:0')
# torch.Size([484581])lete
# tensor(2457, device='cuda:0')
# torch.Size([831330])lete
# tensor(3975, device='cuda:0')
# torch.Size([702643])lete
# tensor(3185, device='cuda:0')
# torch.Size([439389])lete
# tensor(2604, device='cuda:0')
# torch.Size([803843])lete
# tensor(3785, device='cuda:0')
# torch.Size([720370])lete
# tensor(3444, device='cuda:0')
# torch.Size([290050])lete
# tensor(1928, device='cuda:0')
# torch.Size([577948])lete
# tensor(2977, device='cuda:0')
# torch.Size([443165])lete
# tensor(2618, device='cuda:0')
# torch.Size([630040])lete
# tensor(3122, device='cuda:0')
# torch.Size([493686])lete
# tensor(2829, device='cuda:0')
# torch.Size([673685])lete
# tensor(3698, device='cuda:0')
# torch.Size([926748])lete
# tensor(4161, device='cuda:0')
# torch.Size([724103])lete
# tensor(3255, device='cuda:0')
# torch.Size([639304])lete
# tensor(3206, device='cuda:0')
# torch.Size([818278])lete
# tensor(3563, device='cuda:0')
# torch.Size([699068])lete
# tensor(3302, device='cuda:0')
# torch.Size([623946])lete
# tensor(3044, device='cuda:0')
# torch.Size([518234])lete
# tensor(2990, device='cuda:0')
# torch.Size([352571])lete
# tensor(2117, device='cuda:0')
# torch.Size([527823])lete
# tensor(2973, device='cuda:0')
# torch.Size([718498])lete
# tensor(3314, device='cuda:0')
# torch.Size([807364])lete
# tensor(4045, device='cuda:0')
# torch.Size([546952])lete
# tensor(2936, device='cuda:0')
# torch.Size([470318])lete
# tensor(2980, device='cuda:0')
# torch.Size([423198])lete
# tensor(2682, device='cuda:0')
# torch.Size([665209])lete
# tensor(3453, device='cuda:0')
# torch.Size([445383])lete
# tensor(2797, device='cuda:0')
# torch.Size([677052])lete
# tensor(3448, device='cuda:0')
# torch.Size([631990])lete
# tensor(3264, device='cuda:0')
# torch.Size([580120])lete
# tensor(3021, device='cuda:0')
# torch.Size([627210])lete
# tensor(3106, device='cuda:0')
# torch.Size([596000])lete
# tensor(3304, device='cuda:0')
# torch.Size([477191])lete
# tensor(2720, device='cuda:0')
# torch.Size([408550])lete
# tensor(2558, device='cuda:0')
# torch.Size([403232])lete
# tensor(2430, device='cuda:0')
# torch.Size([654194])lete
# tensor(3092, device='cuda:0')
# torch.Size([507799])lete
# tensor(2779, device='cuda:0')
# torch.Size([513574])lete
# tensor(2809, device='cuda:0')
# torch.Size([343747])lete
# tensor(2180, device='cuda:0')
# torch.Size([604861])lete
# tensor(3052, device='cuda:0')
# torch.Size([448281])lete
# tensor(2681, device='cuda:0')
# torch.Size([392297])lete
# tensor(2131, device='cuda:0')
# torch.Size([402647])lete
# tensor(2582, device='cuda:0')
# torch.Size([452566])lete
# tensor(2672, device='cuda:0')
# torch.Size([575961])lete
# tensor(3118, device='cuda:0')
# torch.Size([836340])lete
# tensor(3818, device='cuda:0')
# torch.Size([674920])lete
# tensor(3634, device='cuda:0')
# torch.Size([643915])lete
# tensor(3187, device='cuda:0')
# torch.Size([623719])lete
# tensor(3461, device='cuda:0')
# torch.Size([380630])lete
# tensor(2378, device='cuda:0')
# torch.Size([701712])lete
# tensor(3417, device='cuda:0')
# torch.Size([454735])lete
# tensor(2811, device='cuda:0')
# torch.Size([769439])lete
# tensor(3458, device='cuda:0')
# torch.Size([577034])lete
# tensor(2912, device='cuda:0')
# torch.Size([535002])lete
# tensor(3011, device='cuda:0')
# torch.Size([435440])lete
# tensor(2606, device='cuda:0')
# torch.Size([760542])lete
# tensor(3928, device='cuda:0')
# torch.Size([448841])lete
# tensor(2789, device='cuda:0')
# torch.Size([606504])lete
# tensor(3299, device='cuda:0')
# torch.Size([879643])lete
# tensor(3892, device='cuda:0')
# torch.Size([502428])lete
# tensor(2889, device='cuda:0')
# torch.Size([905761])lete
# tensor(3941, device='cuda:0')
# torch.Size([850123])lete
# tensor(3745, device='cuda:0')
# torch.Size([739321])lete
# tensor(3455, device='cuda:0')
# torch.Size([597389])lete
# tensor(3023, device='cuda:0')
# torch.Size([839650])lete
# tensor(3222, device='cuda:0')
# torch.Size([522255])lete
# tensor(2985, device='cuda:0')
# torch.Size([550952])lete
# tensor(2996, device='cuda:0')
# torch.Size([720034])lete
# tensor(3139, device='cuda:0')
# torch.Size([731797])lete
# tensor(3591, device='cuda:0')
# torch.Size([653221])lete
# tensor(3372, device='cuda:0')
# torch.Size([605578])lete
# tensor(3191, device='cuda:0')
# torch.Size([640209])lete
# tensor(3008, device='cuda:0')
# torch.Size([699997])lete
# tensor(3457, device='cuda:0')
# torch.Size([589363])lete
# tensor(3376, device='cuda:0')
# torch.Size([775731])lete
# tensor(3211, device='cuda:0')
# torch.Size([872838])lete
# tensor(3926, device='cuda:0')
# torch.Size([649277])lete
# tensor(3269, device='cuda:0')
# torch.Size([736148])lete
# tensor(3364, device='cuda:0')
# torch.Size([521169])lete
# tensor(2695, device='cuda:0')
# torch.Size([453658])lete
# tensor(3181, device='cuda:0')
# torch.Size([734479])lete
# tensor(3690, device='cuda:0')
# torch.Size([552401])lete
# tensor(2564, device='cuda:0')
# torch.Size([413386])lete
# tensor(2451, device='cuda:0')
# torch.Size([453814])lete
# tensor(2687, device='cuda:0')
# torch.Size([718047])lete
# tensor(3785, device='cuda:0')
# torch.Size([860031])lete
# tensor(3913, device='cuda:0')
# torch.Size([389622])lete
# tensor(2286, device='cuda:0')
# torch.Size([639239])lete
# tensor(2946, device='cuda:0')
# torch.Size([495132])lete
# tensor(2714, device='cuda:0')
# torch.Size([455589])lete
# tensor(2501, device='cuda:0')
# torch.Size([727039])lete
# tensor(3445, device='cuda:0')
# torch.Size([405738])lete
# tensor(2627, device='cuda:0')
# torch.Size([606013])lete
# tensor(3322, device='cuda:0')
# torch.Size([627125])lete
# tensor(3156, device='cuda:0')
# torch.Size([692369])lete
# tensor(3454, device='cuda:0')
# torch.Size([535370])lete
# tensor(2870, device='cuda:0')
# torch.Size([603184])lete
# tensor(2952, device='cuda:0')
# torch.Size([454215])lete
# tensor(3164, device='cuda:0')
# torch.Size([526152])lete
# tensor(2768, device='cuda:0')
# torch.Size([375886])lete
# tensor(2843, device='cuda:0')
# torch.Size([648356])lete
# tensor(3396, device='cuda:0')
# torch.Size([450015])lete
# tensor(2817, device='cuda:0')
# torch.Size([509269])lete
# tensor(2779, device='cuda:0')
# torch.Size([524520])lete
# tensor(3121, device='cuda:0')
# torch.Size([331886])lete
# tensor(2163, device='cuda:0')
# torch.Size([539221])lete
# tensor(3221, device='cuda:0')
# torch.Size([526582])lete
# tensor(2863, device='cuda:0')
# torch.Size([556160])lete
# tensor(3256, device='cuda:0')
# torch.Size([517397])lete
# tensor(2944, device='cuda:0')
# torch.Size([400317])lete
# tensor(2597, device='cuda:0')
# torch.Size([387728])lete
# tensor(2431, device='cuda:0')
# torch.Size([556678])lete
# tensor(2941, device='cuda:0')
# torch.Size([480187])lete
# tensor(2847, device='cuda:0')
# torch.Size([511835])lete
# tensor(3083, device='cuda:0')
# torch.Size([563803])lete
# tensor(2952, device='cuda:0')
# torch.Size([594745])lete
# tensor(3080, device='cuda:0')
# torch.Size([603504])lete
# tensor(3203, device='cuda:0')
# torch.Size([976317])lete
# tensor(4459, device='cuda:0')
# torch.Size([518086])lete
# tensor(2859, device='cuda:0')
# torch.Size([344646])lete
# tensor(2277, device='cuda:0')
# torch.Size([583371])lete
# tensor(3111, device='cuda:0')
# torch.Size([703959])lete
# tensor(3492, device='cuda:0')
# torch.Size([401625])lete
# tensor(2513, device='cuda:0')
# torch.Size([642086])lete
# tensor(3072, device='cuda:0')
# torch.Size([702732])lete
# tensor(3537, device='cuda:0')
# torch.Size([472627])lete
# tensor(2660, device='cuda:0')
# torch.Size([443552])lete
# tensor(2603, device='cuda:0')
# torch.Size([557471])lete
# tensor(3099, device='cuda:0')
# torch.Size([579751])lete
# tensor(3091, device='cuda:0')
# torch.Size([635248])lete
# tensor(3202, device='cuda:0')
# torch.Size([591038])lete
# tensor(3406, device='cuda:0')
# torch.Size([374117])lete
# tensor(2415, device='cuda:0')
# torch.Size([587465])lete
# tensor(3059, device='cuda:0')
# torch.Size([607146])lete
# tensor(2897, device='cuda:0')
# torch.Size([681317])lete
# tensor(3566, device='cuda:0')
# torch.Size([591041])lete
# tensor(2927, device='cuda:0')
# torch.Size([720196])lete
# tensor(3249, device='cuda:0')
# torch.Size([655096])lete
# tensor(3126, device='cuda:0')
# torch.Size([757828])lete
# tensor(3573, device='cuda:0')
# torch.Size([1148774])ete
# tensor(4206, device='cuda:0')
# torch.Size([716768])lete
# tensor(3396, device='cuda:0')
# torch.Size([649469])lete
# tensor(3178, device='cuda:0')
# torch.Size([1020317])ete
# tensor(4102, device='cuda:0')
# torch.Size([549610])lete
# tensor(3044, device='cuda:0')
# torch.Size([512394])lete
# tensor(2624, device='cuda:0')
# torch.Size([506393])lete
# tensor(3174, device='cuda:0')
# torch.Size([619773])lete
# tensor(3225, device='cuda:0')
# torch.Size([500853])lete
# tensor(2902, device='cuda:0')
# torch.Size([565889])lete
# tensor(2931, device='cuda:0')
# torch.Size([774219])lete
# tensor(3804, device='cuda:0')
# torch.Size([641570])lete
# tensor(2967, device='cuda:0')
# torch.Size([545671])lete
# tensor(3199, device='cuda:0')
# torch.Size([681094])lete
# tensor(3274, device='cuda:0')
# torch.Size([581006])lete
# tensor(3033, device='cuda:0')
# torch.Size([291756])lete
# tensor(2210, device='cuda:0')
# torch.Size([656640])lete
# tensor(3424, device='cuda:0')
# torch.Size([318380])lete
# tensor(2261, device='cuda:0')
# torch.Size([505810])lete
# tensor(2994, device='cuda:0')
# torch.Size([577762])lete
# tensor(3425, device='cuda:0')
# torch.Size([478548])lete
# tensor(2753, device='cuda:0')
# torch.Size([631870])lete
# tensor(2978, device='cuda:0')
# torch.Size([482154])lete
# tensor(2612, device='cuda:0')
# torch.Size([467189])lete
# tensor(2730, device='cuda:0')
# torch.Size([525121])lete
# tensor(3227, device='cuda:0')
# torch.Size([444124])lete
# tensor(2751, device='cuda:0')
# torch.Size([576690])lete
# tensor(3314, device='cuda:0')
# torch.Size([618823])lete
# tensor(3384, device='cuda:0')
# torch.Size([390113])lete
# tensor(2370, device='cuda:0')
# torch.Size([527656])lete
# tensor(2995, device='cuda:0')
# torch.Size([522680])lete
# tensor(2831, device='cuda:0')
# torch.Size([569774])lete
# tensor(3001, device='cuda:0')
# torch.Size([475186])lete
# tensor(2605, device='cuda:0')
# torch.Size([577580])lete
# tensor(2926, device='cuda:0')
# torch.Size([587233])lete
# tensor(3102, device='cuda:0')
# torch.Size([612157])lete
# tensor(2955, device='cuda:0')
# torch.Size([542545])lete
# tensor(3005, device='cuda:0')
# torch.Size([541715])lete
# tensor(3108, device='cuda:0')
# torch.Size([686391])lete
# tensor(3213, device='cuda:0')
# torch.Size([672268])lete
# tensor(3187, device='cuda:0')
# torch.Size([581879])lete
# tensor(2958, device='cuda:0')
# torch.Size([733377])lete
# tensor(3314, device='cuda:0')
# torch.Size([519234])lete
# tensor(2810, device='cuda:0')
# torch.Size([1208255])ete
# tensor(4815, device='cuda:0')
# torch.Size([534757])lete
# tensor(2600, device='cuda:0')
# torch.Size([578420])lete
# tensor(3135, device='cuda:0')
# torch.Size([497105])lete
# tensor(2542, device='cuda:0')
# torch.Size([728266])lete
# tensor(3546, device='cuda:0')
# torch.Size([573900])lete
# tensor(2985, device='cuda:0')
# torch.Size([519715])lete
# tensor(2692, device='cuda:0')
# torch.Size([653739])lete
# tensor(3057, device='cuda:0')
# torch.Size([757446])lete
# tensor(3336, device='cuda:0')
# torch.Size([597609])lete
# tensor(3194, device='cuda:0')
# torch.Size([872578])lete
# tensor(3896, device='cuda:0')
# torch.Size([687311])lete
# tensor(3495, device='cuda:0')
# torch.Size([905644])lete
# tensor(3990, device='cuda:0')
# torch.Size([810108])lete
# tensor(3426, device='cuda:0')
# torch.Size([615991])lete
# tensor(3134, device='cuda:0')
# torch.Size([581495])lete
# tensor(3266, device='cuda:0')
# torch.Size([561084])lete
# tensor(2800, device='cuda:0')
# torch.Size([668423])lete
# tensor(3312, device='cuda:0')
# torch.Size([650874])lete
# tensor(3245, device='cuda:0')
# torch.Size([591391])lete
# tensor(3054, device='cuda:0')
# torch.Size([574222])lete
# tensor(2966, device='cuda:0')
# torch.Size([528791])lete
# tensor(2786, device='cuda:0')
# torch.Size([644351])lete
# tensor(3249, device='cuda:0')
# torch.Size([692458])lete
# tensor(3558, device='cuda:0')
# torch.Size([430392])lete
# tensor(2965, device='cuda:0')
# torch.Size([543429])lete
# tensor(3127, device='cuda:0')
# torch.Size([484532])lete
# tensor(3100, device='cuda:0')
# torch.Size([693636])lete
# tensor(3648, device='cuda:0')
# torch.Size([512403])lete
# tensor(2947, device='cuda:0')
# torch.Size([651897])lete
# tensor(3646, device='cuda:0')
# torch.Size([483243])lete
# tensor(2647, device='cuda:0')
# torch.Size([529131])lete
# tensor(2841, device='cuda:0')
# torch.Size([764497])lete
# tensor(3678, device='cuda:0')
# torch.Size([395657])lete
# tensor(2454, device='cuda:0')
# torch.Size([597834])lete
# tensor(3323, device='cuda:0')
# torch.Size([587784])lete
# tensor(3145, device='cuda:0')
# torch.Size([448176])lete
# tensor(2853, device='cuda:0')
# torch.Size([285613])lete
# tensor(1865, device='cuda:0')
# torch.Size([414930])lete
# tensor(2499, device='cuda:0')
# torch.Size([646617])lete
# tensor(3312, device='cuda:0')
# torch.Size([555918])lete
# tensor(3170, device='cuda:0')
# torch.Size([638649])lete
# tensor(3470, device='cuda:0')
# torch.Size([629762])lete
# tensor(3446, device='cuda:0')
# torch.Size([580247])lete
# tensor(3225, device='cuda:0')
# torch.Size([443425])lete
# tensor(2682, device='cuda:0')
# torch.Size([496290])lete
# tensor(2825, device='cuda:0')
# torch.Size([391940])lete
# tensor(2440, device='cuda:0')
# torch.Size([588102])lete
# tensor(3161, device='cuda:0')
# torch.Size([526940])lete
# tensor(2795, device='cuda:0')
# torch.Size([575366])lete
# tensor(3077, device='cuda:0')
# torch.Size([564485])lete
# tensor(3010, device='cuda:0')
# torch.Size([715139])lete
# tensor(3330, device='cuda:0')
# torch.Size([855366])lete
# tensor(3655, device='cuda:0')
# torch.Size([795792])lete
# tensor(3821, device='cuda:0')
# torch.Size([787283])lete
# tensor(3723, device='cuda:0')
# torch.Size([729539])lete
# tensor(3511, device='cuda:0')
# torch.Size([464497])lete
# tensor(2684, device='cuda:0')
# torch.Size([542711])lete
# tensor(3283, device='cuda:0')
# torch.Size([617808])lete
# tensor(2998, device='cuda:0')
# torch.Size([858993])lete
# tensor(3767, device='cuda:0')
# torch.Size([600863])lete
# tensor(2905, device='cuda:0')
# torch.Size([508500])lete
# tensor(3159, device='cuda:0')
# torch.Size([644353])lete
# tensor(3194, device='cuda:0')
# torch.Size([624877])lete
# tensor(3235, device='cuda:0')
# torch.Size([732426])lete
# tensor(3318, device='cuda:0')
# torch.Size([576408])lete
# tensor(3048, device='cuda:0')
# torch.Size([607586])lete
# tensor(3318, device='cuda:0')
# torch.Size([641237])lete
# tensor(3236, device='cuda:0')
# torch.Size([746515])lete
# tensor(3349, device='cuda:0')
# torch.Size([583135])lete
# tensor(3137, device='cuda:0')
# torch.Size([555019])lete
# tensor(3163, device='cuda:0')
# torch.Size([712518])lete
# tensor(3441, device='cuda:0')
# torch.Size([514209])lete
# tensor(3040, device='cuda:0')
# torch.Size([808744])lete
# tensor(3765, device='cuda:0')
# torch.Size([639669])lete
# tensor(3257, device='cuda:0')
# torch.Size([628059])lete
# tensor(3468, device='cuda:0')
# torch.Size([545138])lete
# tensor(3549, device='cuda:0')
# torch.Size([661164])lete
# tensor(3606, device='cuda:0')
# torch.Size([564983])lete
# tensor(2833, device='cuda:0')
# torch.Size([877417])lete
# tensor(3604, device='cuda:0')
# torch.Size([640000])lete
# tensor(3276, device='cuda:0')
# torch.Size([702226])lete
# tensor(3458, device='cuda:0')
# torch.Size([756990])lete
# tensor(3472, device='cuda:0')
# torch.Size([544380])lete
# tensor(2815, device='cuda:0')
# torch.Size([422226])lete
# tensor(2467, device='cuda:0')
# torch.Size([432229])lete
# tensor(2629, device='cuda:0')
# torch.Size([613141])lete
# tensor(3604, device='cuda:0')
# torch.Size([559948])lete
# tensor(3144, device='cuda:0')
# torch.Size([620251])lete
# tensor(3353, device='cuda:0')
# torch.Size([575621])lete
# tensor(3270, device='cuda:0')
# torch.Size([417946])lete
# tensor(2561, device='cuda:0')
# torch.Size([405782])lete
# tensor(2509, device='cuda:0')
# torch.Size([472254])lete
# tensor(3025, device='cuda:0')
# torch.Size([497000])lete
# tensor(3299, device='cuda:0')
# torch.Size([673361])lete
# tensor(3267, device='cuda:0')
# torch.Size([727787])lete
# tensor(3521, device='cuda:0')
# torch.Size([401395])lete
# tensor(2686, device='cuda:0')
# torch.Size([408376])lete
# tensor(2367, device='cuda:0')
# torch.Size([546991])lete
# tensor(2911, device='cuda:0')
# torch.Size([543035])lete
# tensor(3201, device='cuda:0')
# torch.Size([540239])lete
# tensor(3031, device='cuda:0')
# torch.Size([354962])lete
# tensor(2327, device='cuda:0')
# torch.Size([592779])lete
# tensor(3416, device='cuda:0')
# torch.Size([497314])lete
# tensor(2795, device='cuda:0')
# torch.Size([453457])lete
# tensor(2740, device='cuda:0')
# torch.Size([604711])lete
# tensor(3261, device='cuda:0')
# torch.Size([462004])lete
# tensor(2556, device='cuda:0')
# torch.Size([669996])lete
# tensor(3187, device='cuda:0')
# torch.Size([692508])lete
# tensor(3421, device='cuda:0')
# torch.Size([492955])lete
# tensor(3037, device='cuda:0')
# torch.Size([554079])lete
# tensor(2884, device='cuda:0')
# torch.Size([573994])lete
# tensor(3088, device='cuda:0')
# torch.Size([482858])lete
# tensor(2840, device='cuda:0')
# torch.Size([615133])lete
# tensor(3140, device='cuda:0')
# torch.Size([955770])lete
# tensor(4043, device='cuda:0')
# torch.Size([485626])lete
# tensor(2862, device='cuda:0')
# torch.Size([623923])lete
# tensor(3392, device='cuda:0')
# torch.Size([534918])lete
# tensor(2971, device='cuda:0')
# torch.Size([529714])lete
# tensor(2955, device='cuda:0')
# torch.Size([824961])lete
# tensor(3840, device='cuda:0')
# torch.Size([964864])lete
# tensor(4349, device='cuda:0')
# torch.Size([474368])lete
# tensor(2848, device='cuda:0')
# torch.Size([451981])lete
# tensor(2928, device='cuda:0')
# torch.Size([594866])lete
# tensor(3023, device='cuda:0')
# torch.Size([500739])lete
# tensor(2770, device='cuda:0')
# torch.Size([484359])lete
# tensor(2934, device='cuda:0')
# torch.Size([874287])lete
# tensor(3748, device='cuda:0')
# torch.Size([580893])lete
# tensor(3243, device='cuda:0')
# torch.Size([462886])lete
# tensor(2625, device='cuda:0')
# torch.Size([655383])lete
# tensor(3163, device='cuda:0')
# torch.Size([819670])lete
# tensor(3665, device='cuda:0')
# torch.Size([768862])lete
# tensor(3607, device='cuda:0')
# torch.Size([721068])lete
# tensor(3168, device='cuda:0')
# torch.Size([739303])lete
# tensor(3352, device='cuda:0')
# torch.Size([766795])lete
# tensor(3309, device='cuda:0')
# torch.Size([561120])lete
# tensor(2947, device='cuda:0')
# torch.Size([764928])lete
# tensor(3463, device='cuda:0')
# torch.Size([656197])lete
# tensor(3204, device='cuda:0')
# torch.Size([892710])lete
# tensor(3661, device='cuda:0')
# torch.Size([803742])lete
# tensor(4060, device='cuda:0')
# torch.Size([564581])lete
# tensor(2990, device='cuda:0')
# torch.Size([447824])lete
# tensor(2660, device='cuda:0')
# torch.Size([614429])lete
# tensor(2917, device='cuda:0')
# torch.Size([592561])lete
# tensor(3311, device='cuda:0')
# torch.Size([723220])lete
# tensor(3373, device='cuda:0')
# torch.Size([636284])lete
# tensor(3508, device='cuda:0')
# torch.Size([515897])lete
# tensor(2913, device='cuda:0')
# torch.Size([292181])lete
# tensor(1947, device='cuda:0')
# torch.Size([590773])lete
# tensor(2950, device='cuda:0')
# torch.Size([520198])lete
# tensor(2964, device='cuda:0')
# torch.Size([359308])lete
# tensor(2416, device='cuda:0')
# torch.Size([396116])lete
# tensor(2667, device='cuda:0')
# torch.Size([478222])lete
# tensor(3037, device='cuda:0')
# torch.Size([459975])lete
# tensor(2851, device='cuda:0')
# torch.Size([436106])lete
# tensor(2685, device='cuda:0')
# torch.Size([556291])lete
# tensor(3336, device='cuda:0')
# torch.Size([579382])lete
# tensor(3345, device='cuda:0')
# torch.Size([533426])lete
# tensor(2975, device='cuda:0')
# torch.Size([638400])lete
# tensor(3122, device='cuda:0')
# torch.Size([622547])lete
# tensor(3033, device='cuda:0')
# torch.Size([530539])lete
# tensor(3060, device='cuda:0')
# torch.Size([690022])lete
# tensor(3235, device='cuda:0')
# torch.Size([388976])lete
# tensor(2503, device='cuda:0')
# torch.Size([425962])lete
# tensor(2675, device='cuda:0')
# torch.Size([487426])lete
# tensor(2875, device='cuda:0')
# torch.Size([451977])lete
# tensor(2535, device='cuda:0')
# torch.Size([383207])lete
# tensor(2225, device='cuda:0')
# torch.Size([497398])lete
# tensor(2816, device='cuda:0')
# torch.Size([523605])lete
# tensor(2671, device='cuda:0')
# torch.Size([440662])lete
# tensor(2931, device='cuda:0')
# torch.Size([556015])lete
# tensor(2796, device='cuda:0')
# torch.Size([464670])lete
# tensor(3063, device='cuda:0')
# torch.Size([656484])lete
# tensor(3487, device='cuda:0')
# torch.Size([578395])lete
# tensor(2816, device='cuda:0')
# torch.Size([511651])lete
# tensor(3178, device='cuda:0')
# torch.Size([588103])lete
# tensor(3005, device='cuda:0')
# torch.Size([685199])lete
# tensor(3266, device='cuda:0')
# torch.Size([398017])lete
# tensor(2389, device='cuda:0')
# torch.Size([660453])lete
# tensor(3320, device='cuda:0')
# torch.Size([700413])lete
# tensor(3370, device='cuda:0')
# torch.Size([517184])lete
# tensor(2781, device='cuda:0')
# torch.Size([470171])lete
# tensor(2841, device='cuda:0')
# torch.Size([618745])lete
# tensor(3022, device='cuda:0')
# torch.Size([612865])lete
# tensor(3425, device='cuda:0')
# torch.Size([464789])lete
# tensor(2620, device='cuda:0')
# torch.Size([404956])lete
# tensor(2073, device='cuda:0')
# torch.Size([647651])lete
# tensor(3328, device='cuda:0')
# torch.Size([574329])lete
# tensor(2856, device='cuda:0')
# torch.Size([773498])lete
# tensor(3247, device='cuda:0')
# torch.Size([654290])lete
# tensor(2992, device='cuda:0')
# torch.Size([694851])lete
# tensor(3468, device='cuda:0')
# torch.Size([697587])lete
# tensor(3269, device='cuda:0')
# torch.Size([768165])lete
# tensor(4017, device='cuda:0')
# torch.Size([638345])lete
# tensor(3461, device='cuda:0')
# torch.Size([670847])lete
# tensor(3152, device='cuda:0')
# torch.Size([623596])lete
# tensor(2865, device='cuda:0')
# torch.Size([733015])lete
# tensor(3062, device='cuda:0')
# torch.Size([675023])lete
# tensor(3279, device='cuda:0')
# torch.Size([913696])lete
# tensor(3723, device='cuda:0')
# torch.Size([636313])lete
# tensor(3396, device='cuda:0')
# torch.Size([652337])lete
# tensor(3222, device='cuda:0')
# torch.Size([571104])lete
# tensor(3082, device='cuda:0')
# torch.Size([508066])lete
# tensor(2662, device='cuda:0')
# torch.Size([766327])lete
# tensor(3767, device='cuda:0')
# torch.Size([644415])lete
# tensor(3106, device='cuda:0')
# torch.Size([624456])lete
# tensor(3135, device='cuda:0')
# torch.Size([634000])lete
# tensor(3009, device='cuda:0')
# torch.Size([649450])lete
# tensor(3399, device='cuda:0')
# torch.Size([561351])lete
# tensor(2716, device='cuda:0')
# torch.Size([606174])lete
# tensor(2935, device='cuda:0')
# torch.Size([527341])lete
# tensor(2878, device='cuda:0')
# torch.Size([585506])lete
# tensor(2992, device='cuda:0')
# torch.Size([448631])lete
# tensor(2621, device='cuda:0')
# torch.Size([427503])lete
# tensor(2992, device='cuda:0')
# torch.Size([488597])lete
# tensor(2884, device='cuda:0')
# torch.Size([456882])lete
# tensor(2933, device='cuda:0')
# torch.Size([561260])lete
# tensor(3132, device='cuda:0')
# torch.Size([520683])lete
# tensor(3021, device='cuda:0')
# torch.Size([500145])lete
# tensor(2912, device='cuda:0')
# torch.Size([444037])lete
# tensor(2695, device='cuda:0')
# torch.Size([638735])lete
# tensor(3309, device='cuda:0')
# torch.Size([506932])lete
# tensor(2745, device='cuda:0')
# torch.Size([656984])lete
# tensor(3067, device='cuda:0')
# torch.Size([569595])lete
# tensor(3172, device='cuda:0')
# torch.Size([485174])lete
# tensor(2738, device='cuda:0')
# torch.Size([706257])lete
# tensor(3348, device='cuda:0')
# torch.Size([433277])lete
# tensor(2707, device='cuda:0')
# torch.Size([526580])lete
# tensor(3121, device='cuda:0')
# torch.Size([952284])lete
# tensor(4487, device='cuda:0')
# torch.Size([667588])lete
# tensor(3244, device='cuda:0')
# torch.Size([659082])lete
# tensor(3514, device='cuda:0')
# torch.Size([491873])lete
# tensor(2720, device='cuda:0')
# torch.Size([556929])lete
# tensor(2854, device='cuda:0')
# torch.Size([743391])lete
# tensor(3154, device='cuda:0')
# torch.Size([406779])lete
# tensor(2520, device='cuda:0')
# torch.Size([548627])lete
# tensor(2494, device='cuda:0')
# torch.Size([1115045])ete
# tensor(4472, device='cuda:0')
# torch.Size([447519])lete
# tensor(2438, device='cuda:0')
# torch.Size([587586])lete
# tensor(3120, device='cuda:0')
# torch.Size([657064])lete
# tensor(2954, device='cuda:0')
# torch.Size([762674])lete
# tensor(3204, device='cuda:0')
# torch.Size([731151])lete
# tensor(3450, device='cuda:0')
# torch.Size([676550])lete
# tensor(3435, device='cuda:0')
# torch.Size([742294])lete
# tensor(2951, device='cuda:0')
# torch.Size([634883])lete
# tensor(3319, device='cuda:0')
# torch.Size([591583])lete
# tensor(3192, device='cuda:0')
# torch.Size([836207])lete
# tensor(3996, device='cuda:0')
# torch.Size([648137])lete
# tensor(3140, device='cuda:0')
# torch.Size([579347])lete
# tensor(3001, device='cuda:0')
# torch.Size([553991])lete
# tensor(3192, device='cuda:0')
# torch.Size([398053])lete
# tensor(2040, device='cuda:0')
# torch.Size([866448])lete
# tensor(4044, device='cuda:0')
# torch.Size([485125])lete
# tensor(3017, device='cuda:0')
# torch.Size([484835])lete
# tensor(2507, device='cuda:0')
# torch.Size([685778])lete
# tensor(3564, device='cuda:0')
# torch.Size([905702])lete
# tensor(3911, device='cuda:0')
# torch.Size([652251])lete
# tensor(3300, device='cuda:0')
# torch.Size([620392])lete
# tensor(3330, device='cuda:0')
# torch.Size([675210])lete
# tensor(3570, device='cuda:0')
# torch.Size([509204])lete
# tensor(2937, device='cuda:0')
# torch.Size([586652])lete
# tensor(3257, device='cuda:0')
# torch.Size([570538])lete
# tensor(2893, device='cuda:0')
# torch.Size([579062])lete
# tensor(2839, device='cuda:0')
# torch.Size([587903])lete
# tensor(2920, device='cuda:0')
# torch.Size([460309])lete
# tensor(2316, device='cuda:0')
# torch.Size([709677])lete
# tensor(3411, device='cuda:0')
# torch.Size([486668])lete
# tensor(2658, device='cuda:0')
# torch.Size([529444])lete
# tensor(2850, device='cuda:0')
# torch.Size([492248])lete
# tensor(2775, device='cuda:0')
# torch.Size([536324])lete
# tensor(3047, device='cuda:0')
# torch.Size([551621])lete
# tensor(3086, device='cuda:0')
# torch.Size([518230])lete
# tensor(2976, device='cuda:0')
# torch.Size([401138])lete
# tensor(2220, device='cuda:0')
# torch.Size([534086])lete
# tensor(2993, device='cuda:0')
# torch.Size([620385])lete
# tensor(3361, device='cuda:0')
# torch.Size([533716])lete
# tensor(3211, device='cuda:0')
# torch.Size([719407])lete
# tensor(3768, device='cuda:0')
# torch.Size([514079])lete
# tensor(2720, device='cuda:0')
# torch.Size([542995])lete
# tensor(2598, device='cuda:0')
# torch.Size([484453])lete
# tensor(2570, device='cuda:0')
# torch.Size([746908])lete
# tensor(3476, device='cuda:0')
# torch.Size([641795])lete
# tensor(3455, device='cuda:0')
# torch.Size([659492])lete
# tensor(2816, device='cuda:0')
# torch.Size([573796])lete
# tensor(2787, device='cuda:0')
# torch.Size([556707])lete
# tensor(2905, device='cuda:0')
# torch.Size([797331])lete
# tensor(3841, device='cuda:0')
# torch.Size([512643])lete
# tensor(2523, device='cuda:0')
# torch.Size([519898])lete
# tensor(2860, device='cuda:0')
# torch.Size([506703])lete
# tensor(2442, device='cuda:0')
# torch.Size([739744])lete
# tensor(3678, device='cuda:0')
# torch.Size([601515])lete
# tensor(3037, device='cuda:0')
# torch.Size([690162])lete
# tensor(3193, device='cuda:0')
# torch.Size([680539])lete
# tensor(3452, device='cuda:0')
# torch.Size([834028])lete
# tensor(3410, device='cuda:0')
# torch.Size([687009])lete
# tensor(3463, device='cuda:0')
# torch.Size([626345])lete
# tensor(3042, device='cuda:0')
# torch.Size([831555])lete
# tensor(3741, device='cuda:0')
# torch.Size([647745])lete
# tensor(2986, device='cuda:0')
# torch.Size([746646])lete
# tensor(3524, device='cuda:0')
# torch.Size([681510])lete
# tensor(3449, device='cuda:0')
# torch.Size([476872])lete
# tensor(2678, device='cuda:0')
# torch.Size([568744])lete
# tensor(2717, device='cuda:0')
# torch.Size([662130])lete
# tensor(3099, device='cuda:0')
# torch.Size([624949])lete
# tensor(3103, device='cuda:0')
# torch.Size([904729])lete
# tensor(4023, device='cuda:0')
# torch.Size([614534])lete
# tensor(3039, device='cuda:0')
# torch.Size([460528])lete
# tensor(2870, device='cuda:0')
# torch.Size([741765])lete
# tensor(3366, device='cuda:0')
# torch.Size([453018])lete
# tensor(2979, device='cuda:0')
# torch.Size([496615])lete
# tensor(2807, device='cuda:0')
# torch.Size([783707])lete
# tensor(3552, device='cuda:0')
# torch.Size([608099])lete
# tensor(3158, device='cuda:0')
# torch.Size([489514])lete
# tensor(2641, device='cuda:0')
# torch.Size([457157])lete
# tensor(2707, device='cuda:0')
# torch.Size([507270])lete
# tensor(2647, device='cuda:0')
# torch.Size([476477])lete
# tensor(2626, device='cuda:0')
# torch.Size([617172])lete
# tensor(3256, device='cuda:0')
# torch.Size([397362])lete
# tensor(2301, device='cuda:0')
# torch.Size([516627])lete
# tensor(2489, device='cuda:0')
# torch.Size([491085])lete
# tensor(2643, device='cuda:0')
# torch.Size([618721])lete
# tensor(2861, device='cuda:0')
# torch.Size([629711])lete
# tensor(3086, device='cuda:0')
# torch.Size([567565])lete
# tensor(3208, device='cuda:0')
# torch.Size([559637])lete
# tensor(3202, device='cuda:0')
# torch.Size([674017])lete
# tensor(3431, device='cuda:0')
# torch.Size([407352])lete
# tensor(2282, device='cuda:0')
# torch.Size([495706])lete
# tensor(3015, device='cuda:0')
# torch.Size([341711])lete
# tensor(1821, device='cuda:0')
# torch.Size([468263])lete
# tensor(2820, device='cuda:0')
# torch.Size([636955])lete
# tensor(3397, device='cuda:0')
# torch.Size([432915])lete
# tensor(2673, device='cuda:0')
# torch.Size([465500])lete
# tensor(3033, device='cuda:0')
# torch.Size([518989])lete
# tensor(2481, device='cuda:0')
# torch.Size([611423])lete
# tensor(3015, device='cuda:0')
# torch.Size([540561])lete
# tensor(2714, device='cuda:0')
# torch.Size([605358])lete
# tensor(2740, device='cuda:0')
# torch.Size([554074])lete
# tensor(3194, device='cuda:0')
# torch.Size([496048])lete
# tensor(3082, device='cuda:0')
# torch.Size([639188])lete
# tensor(3317, device='cuda:0')
# torch.Size([503085])lete
# tensor(2596, device='cuda:0')
# torch.Size([627041])lete
# tensor(3216, device='cuda:0')
# torch.Size([702855])lete
# tensor(3358, device='cuda:0')
# torch.Size([500656])lete
# tensor(3029, device='cuda:0')
# torch.Size([636060])lete
# tensor(3444, device='cuda:0')
# torch.Size([585861])lete
# tensor(3029, device='cuda:0')
# torch.Size([478556])lete
# tensor(2546, device='cuda:0')
# torch.Size([525250])lete
# tensor(3090, device='cuda:0')
# torch.Size([684777])lete
# tensor(3282, device='cuda:0')
# torch.Size([635075])lete
# tensor(3466, device='cuda:0')
# torch.Size([645511])lete
# tensor(3058, device='cuda:0')
# torch.Size([637718])lete
# tensor(3295, device='cuda:0')
# torch.Size([425290])lete
# tensor(2071, device='cuda:0')
# torch.Size([757226])lete
# tensor(3590, device='cuda:0')
# torch.Size([699183])lete
# tensor(3360, device='cuda:0')
# torch.Size([865547])lete
# tensor(3762, device='cuda:0')
# torch.Size([646763])lete
# tensor(3593, device='cuda:0')
# torch.Size([649581])lete
# tensor(3670, device='cuda:0')
# torch.Size([479957])lete
# tensor(2708, device='cuda:0')
# torch.Size([571497])lete
# tensor(2759, device='cuda:0')
# torch.Size([615761])lete
# tensor(3149, device='cuda:0')
# torch.Size([542846])lete
# tensor(2887, device='cuda:0')
# torch.Size([897637])lete
# tensor(3765, device='cuda:0')
# torch.Size([602947])lete
# tensor(2920, device='cuda:0')
# torch.Size([556939])lete
# tensor(2949, device='cuda:0')
# torch.Size([592079])lete
# tensor(2887, device='cuda:0')
# torch.Size([552417])lete
# tensor(2718, device='cuda:0')
# torch.Size([848239])lete
# tensor(3811, device='cuda:0')
# torch.Size([653926])lete
# tensor(3364, device='cuda:0')
# torch.Size([621470])lete
# tensor(3012, device='cuda:0')
# torch.Size([689276])lete
# tensor(3573, device='cuda:0')
# torch.Size([541181])lete
# tensor(2672, device='cuda:0')
# torch.Size([831666])lete
# tensor(3724, device='cuda:0')
# torch.Size([557353])lete
# tensor(2999, device='cuda:0')
# torch.Size([528915])lete
# tensor(3037, device='cuda:0')
# torch.Size([696630])lete
# tensor(3325, device='cuda:0')
# torch.Size([548465])lete
# tensor(2584, device='cuda:0')
# torch.Size([771537])lete
# tensor(3174, device='cuda:0')
# torch.Size([501940])lete
# tensor(2705, device='cuda:0')
# torch.Size([557686])lete
# tensor(2806, device='cuda:0')
# torch.Size([674892])lete
# tensor(3380, device='cuda:0')
# torch.Size([902567])lete
# tensor(3836, device='cuda:0')
# torch.Size([818013])lete
# tensor(3724, device='cuda:0')
# torch.Size([366354])lete
# tensor(2541, device='cuda:0')
# torch.Size([537869])lete
# tensor(2682, device='cuda:0')
# torch.Size([506202])lete
# tensor(2914, device='cuda:0')
# torch.Size([651702])lete
# tensor(2985, device='cuda:0')
# torch.Size([515193])lete
# tensor(3010, device='cuda:0')
# torch.Size([567057])lete
# tensor(2964, device='cuda:0')
# torch.Size([778161])lete
# tensor(3862, device='cuda:0')
# torch.Size([586212])lete
# tensor(2760, device='cuda:0')
# torch.Size([538111])lete
# tensor(3223, device='cuda:0')
# torch.Size([590967])lete
# tensor(2695, device='cuda:0')
# torch.Size([451165])lete
# tensor(2816, device='cuda:0')
# torch.Size([529907])lete
# tensor(2748, device='cuda:0')
# torch.Size([672115])lete
# tensor(3185, device='cuda:0')
# torch.Size([668438])lete
# tensor(3557, device='cuda:0')
# torch.Size([567785])lete
# tensor(2963, device='cuda:0')
# torch.Size([520377])lete
# tensor(2582, device='cuda:0')
# torch.Size([493639])lete
# tensor(2333, device='cuda:0')
# torch.Size([510982])lete
# tensor(2850, device='cuda:0')
# torch.Size([564784])lete
# tensor(2939, device='cuda:0')
# torch.Size([733672])lete
# tensor(3810, device='cuda:0')
# torch.Size([660794])lete
# tensor(3217, device='cuda:0')
# torch.Size([638277])lete
# tensor(3342, device='cuda:0')
# torch.Size([589225])lete
# tensor(2964, device='cuda:0')
# torch.Size([788750])lete
# tensor(3660, device='cuda:0')
# torch.Size([670030])lete
# tensor(3234, device='cuda:0')
# torch.Size([562863])lete
# tensor(3038, device='cuda:0')
# torch.Size([346419])lete
# tensor(2619, device='cuda:0')
# torch.Size([519218])lete
# tensor(2862, device='cuda:0')
# torch.Size([496951])lete
# tensor(2783, device='cuda:0')
# torch.Size([421546])lete
# tensor(2827, device='cuda:0')
# torch.Size([400915])lete
# tensor(2051, device='cuda:0')
# torch.Size([671509])lete
# tensor(2966, device='cuda:0')
# torch.Size([791511])lete
# tensor(3552, device='cuda:0')
# torch.Size([768168])lete
# tensor(3271, device='cuda:0')
# torch.Size([373519])lete
# tensor(2066, device='cuda:0')
# torch.Size([675704])lete
# tensor(2872, device='cuda:0')
# torch.Size([647393])lete
# tensor(3019, device='cuda:0')
# torch.Size([818836])lete
# tensor(3591, device='cuda:0')
# torch.Size([717856])lete
# tensor(3405, device='cuda:0')
# torch.Size([468914])lete
# tensor(2686, device='cuda:0')
# torch.Size([630083])lete
# tensor(3367, device='cuda:0')
# torch.Size([659852])lete
# tensor(3112, device='cuda:0')
# torch.Size([627435])lete
# tensor(3219, device='cuda:0')
# torch.Size([658621])lete
# tensor(3204, device='cuda:0')
# torch.Size([684223])lete
# tensor(3295, device='cuda:0')
# torch.Size([468629])lete
# tensor(2146, device='cuda:0')
# torch.Size([549829])lete
# tensor(2952, device='cuda:0')
# torch.Size([604823])lete
# tensor(3238, device='cuda:0')
# torch.Size([584256])lete
# tensor(2882, device='cuda:0')
# torch.Size([751792])lete
# tensor(3670, device='cuda:0')
# torch.Size([822562])lete
# tensor(3606, device='cuda:0')
# torch.Size([621735])lete
# tensor(3271, device='cuda:0')
# torch.Size([791422])lete
# tensor(3311, device='cuda:0')
# torch.Size([398157])lete
# tensor(2436, device='cuda:0')
# torch.Size([618025])lete
# tensor(3059, device='cuda:0')
# torch.Size([508600])lete
# tensor(2868, device='cuda:0')
# torch.Size([812472])lete
# tensor(3113, device='cuda:0')
# torch.Size([627469])lete
# tensor(3318, device='cuda:0')
# torch.Size([573945])lete
# tensor(2987, device='cuda:0')
# torch.Size([654916])lete
# tensor(3100, device='cuda:0')
# torch.Size([614385])lete
# tensor(3011, device='cuda:0')
# torch.Size([869777])lete
# tensor(3720, device='cuda:0')
# torch.Size([540875])lete
# tensor(2832, device='cuda:0')
# torch.Size([614384])lete
# tensor(3245, device='cuda:0')
# torch.Size([487228])lete
# tensor(3256, device='cuda:0')
# torch.Size([674776])lete
# tensor(3022, device='cuda:0')
# torch.Size([516258])lete
# tensor(3064, device='cuda:0')
# torch.Size([535621])lete
# tensor(2905, device='cuda:0')
# torch.Size([439405])lete
# tensor(2675, device='cuda:0')
# torch.Size([665576])lete
# tensor(3461, device='cuda:0')
# torch.Size([654022])lete
# tensor(3352, device='cuda:0')
# torch.Size([533236])lete
# tensor(2879, device='cuda:0')
# torch.Size([547210])lete
# tensor(3054, device='cuda:0')
# torch.Size([642274])lete
# tensor(3224, device='cuda:0')
# torch.Size([469845])lete
# tensor(2683, device='cuda:0')
# torch.Size([568298])lete
# tensor(3392, device='cuda:0')
# torch.Size([598730])lete
# tensor(3371, device='cuda:0')
# torch.Size([568534])lete
# tensor(2828, device='cuda:0')
# torch.Size([616941])lete
# tensor(3071, device='cuda:0')
# torch.Size([519741])lete
# tensor(2932, device='cuda:0')
# torch.Size([696899])lete
# tensor(3318, device='cuda:0')
# torch.Size([518166])lete
# tensor(2629, device='cuda:0')
# torch.Size([595186])lete
# tensor(3009, device='cuda:0')
# torch.Size([574325])lete
# tensor(3170, device='cuda:0')
# torch.Size([493525])lete
# tensor(2882, device='cuda:0')
# torch.Size([566924])lete
# tensor(2848, device='cuda:0')
# torch.Size([573112])lete
# tensor(3000, device='cuda:0')
# torch.Size([788698])lete
# tensor(3806, device='cuda:0')
# torch.Size([484729])lete
# tensor(2906, device='cuda:0')
# torch.Size([513720])lete
# tensor(2776, device='cuda:0')
# torch.Size([620669])lete
# tensor(2875, device='cuda:0')
# torch.Size([421261])lete
# tensor(2129, device='cuda:0')
# torch.Size([742578])lete
# tensor(3748, device='cuda:0')
# torch.Size([522723])lete
# tensor(2967, device='cuda:0')
# torch.Size([540408])lete
# tensor(2683, device='cuda:0')
# torch.Size([845204])lete
# tensor(3809, device='cuda:0')
# torch.Size([510027])lete
# tensor(2727, device='cuda:0')
# torch.Size([447785])lete
# tensor(2382, device='cuda:0')
# torch.Size([506699])lete
# tensor(2957, device='cuda:0')
# torch.Size([547134])lete
# tensor(3041, device='cuda:0')
# torch.Size([633792])lete
# tensor(3145, device='cuda:0')
# torch.Size([705639])lete
# tensor(3215, device='cuda:0')
# torch.Size([721339])lete
# tensor(3138, device='cuda:0')
# torch.Size([573476])lete
# tensor(2767, device='cuda:0')
# torch.Size([594681])lete
# tensor(3168, device='cuda:0')
# torch.Size([448151])lete
# tensor(2603, device='cuda:0')
# torch.Size([660027])lete
# tensor(3147, device='cuda:0')
# torch.Size([669438])lete
# tensor(2944, device='cuda:0')
# torch.Size([728940])lete
# tensor(3329, device='cuda:0')
# torch.Size([641837])lete
# tensor(3194, device='cuda:0')
# torch.Size([485461])lete
# tensor(2453, device='cuda:0')
# torch.Size([624091])lete
# tensor(3285, device='cuda:0')
# torch.Size([829526])lete
# tensor(3750, device='cuda:0')
# torch.Size([604736])lete
# tensor(2806, device='cuda:0')
# torch.Size([624962])lete
# tensor(3317, device='cuda:0')
# torch.Size([646208])lete
# tensor(3376, device='cuda:0')
# torch.Size([454968])lete
# tensor(2854, device='cuda:0')
# torch.Size([556857])lete
# tensor(2620, device='cuda:0')
# torch.Size([553236])lete
# tensor(2578, device='cuda:0')
# torch.Size([530628])lete
# tensor(2816, device='cuda:0')
# torch.Size([674096])lete
# tensor(3393, device='cuda:0')
# torch.Size([727899])lete
# tensor(3246, device='cuda:0')
# torch.Size([568386])lete
# tensor(2642, device='cuda:0')
# torch.Size([593305])lete
# tensor(3234, device='cuda:0')
# torch.Size([612074])lete
# tensor(3021, device='cuda:0')
# torch.Size([583327])lete
# tensor(3014, device='cuda:0')
# torch.Size([486333])lete
# tensor(2421, device='cuda:0')
# torch.Size([543899])lete
# tensor(3196, device='cuda:0')
# torch.Size([647993])lete
# tensor(3110, device='cuda:0')
# torch.Size([383918])lete
# tensor(2321, device='cuda:0')
# torch.Size([638172])lete
# tensor(3384, device='cuda:0')
# torch.Size([430609])lete
# tensor(2264, device='cuda:0')
# torch.Size([656702])lete
# tensor(3247, device='cuda:0')
# torch.Size([445281])lete
# tensor(2686, device='cuda:0')
# torch.Size([704796])lete
# tensor(3436, device='cuda:0')
# torch.Size([562459])lete
# tensor(2967, device='cuda:0')
# torch.Size([536663])lete
# tensor(3266, device='cuda:0')
# torch.Size([480842])lete
# tensor(2694, device='cuda:0')
# torch.Size([496037])lete
# tensor(2229, device='cuda:0')
# torch.Size([510467])lete
# tensor(2738, device='cuda:0')
# torch.Size([445769])lete
# tensor(2814, device='cuda:0')
# torch.Size([550783])lete
# tensor(3208, device='cuda:0')
# torch.Size([644555])lete
# tensor(3346, device='cuda:0')
# torch.Size([535391])lete
# tensor(2984, device='cuda:0')
# torch.Size([529891])lete
# tensor(2998, device='cuda:0')
# torch.Size([432965])lete
# tensor(2564, device='cuda:0')
# torch.Size([546159])lete
# tensor(2829, device='cuda:0')
# torch.Size([543564])lete
# tensor(3179, device='cuda:0')
# torch.Size([522676])lete
# tensor(2906, device='cuda:0')
# torch.Size([585220])lete
# tensor(3191, device='cuda:0')
# torch.Size([482968])lete
# tensor(2629, device='cuda:0')
# torch.Size([564904])lete
# tensor(3263, device='cuda:0')
# torch.Size([713097])lete
# tensor(3513, device='cuda:0')
# torch.Size([589801])lete
# tensor(3200, device='cuda:0')
# torch.Size([529317])lete
# tensor(2721, device='cuda:0')
# torch.Size([638788])lete
# tensor(3240, device='cuda:0')
# torch.Size([647531])lete
# tensor(3336, device='cuda:0')
# torch.Size([639771])lete
# tensor(3080, device='cuda:0')
# torch.Size([734907])lete
# tensor(3394, device='cuda:0')
# torch.Size([790788])lete
# tensor(3640, device='cuda:0')
# torch.Size([783995])lete
# tensor(3601, device='cuda:0')
# torch.Size([805264])lete
# tensor(3420, device='cuda:0')
# torch.Size([879892])lete
# tensor(3360, device='cuda:0')
# torch.Size([708571])lete
# tensor(3477, device='cuda:0')
# torch.Size([507740])lete
# tensor(2945, device='cuda:0')
# torch.Size([352105])lete
# tensor(2264, device='cuda:0')
# torch.Size([715256])lete
# tensor(3587, device='cuda:0')
# torch.Size([616305])lete
# tensor(3675, device='cuda:0')
# torch.Size([608367])lete
# tensor(3200, device='cuda:0')
# torch.Size([481238])lete
# tensor(2362, device='cuda:0')
# torch.Size([732728])lete
# tensor(3176, device='cuda:0')
# torch.Size([549348])lete
# tensor(2811, device='cuda:0')
# torch.Size([440664])lete
# tensor(2043, device='cuda:0')
# torch.Size([865306])lete
# tensor(3570, device='cuda:0')
# torch.Size([539726])lete
# tensor(2911, device='cuda:0')
# torch.Size([388343])lete
# tensor(1955, device='cuda:0')
# torch.Size([632350])lete
# tensor(3273, device='cuda:0')
# torch.Size([663856])lete
# tensor(3105, device='cuda:0')
# torch.Size([500047])lete
# tensor(2939, device='cuda:0')
# torch.Size([664700])lete
# tensor(3340, device='cuda:0')
# torch.Size([711883])lete
# tensor(2905, device='cuda:0')
# torch.Size([593632])lete
# tensor(3131, device='cuda:0')
# torch.Size([520592])lete
# tensor(3054, device='cuda:0')
# torch.Size([581352])lete
# tensor(3033, device='cuda:0')
# torch.Size([580391])lete
# tensor(3003, device='cuda:0')
# torch.Size([512449])lete
# tensor(2872, device='cuda:0')
# torch.Size([593160])lete
# tensor(2867, device='cuda:0')
# torch.Size([709447])lete
# tensor(3315, device='cuda:0')
# torch.Size([585669])lete
# tensor(3626, device='cuda:0')
# torch.Size([630970])lete
# tensor(3132, device='cuda:0')
# torch.Size([618633])lete
# tensor(3254, device='cuda:0')
# torch.Size([512971])lete
# tensor(2500, device='cuda:0')
# torch.Size([599276])lete
# tensor(3391, device='cuda:0')
# torch.Size([497503])lete
# tensor(2980, device='cuda:0')
# torch.Size([454618])lete
# tensor(2755, device='cuda:0')
# torch.Size([304820])lete
# tensor(1652, device='cuda:0')
# torch.Size([464205])lete
# tensor(2855, device='cuda:0')
# torch.Size([686928])lete
# tensor(3822, device='cuda:0')
# torch.Size([544326])lete
# tensor(2706, device='cuda:0')
# torch.Size([478398])lete
# tensor(2414, device='cuda:0')
# torch.Size([645817])lete
# tensor(3393, device='cuda:0')
# torch.Size([472658])lete
# tensor(3020, device='cuda:0')
# torch.Size([736549])lete
# tensor(3733, device='cuda:0')
# torch.Size([679203])lete
# tensor(3827, device='cuda:0')
# torch.Size([481140])lete
# tensor(2616, device='cuda:0')
# torch.Size([476228])lete
# tensor(2717, device='cuda:0')
# torch.Size([613687])lete
# tensor(2729, device='cuda:0')
# torch.Size([484533])lete
# tensor(2888, device='cuda:0')
# torch.Size([558477])lete
# tensor(2770, device='cuda:0')
# torch.Size([643009])lete
# tensor(3031, device='cuda:0')
# torch.Size([626341])lete
# tensor(3410, device='cuda:0')
# torch.Size([827292])lete
# tensor(3450, device='cuda:0')
# torch.Size([874612])lete
# tensor(3874, device='cuda:0')
# torch.Size([525529])lete
# tensor(3126, device='cuda:0')
# torch.Size([602035])lete
# tensor(2759, device='cuda:0')
# torch.Size([470468])lete
# tensor(2482, device='cuda:0')
# torch.Size([505970])lete
# tensor(2825, device='cuda:0')
# torch.Size([603732])lete
# tensor(3172, device='cuda:0')
# torch.Size([514467])lete
# tensor(3155, device='cuda:0')
# torch.Size([644171])lete
# tensor(3281, device='cuda:0')
# torch.Size([602420])lete
# tensor(2695, device='cuda:0')
# torch.Size([782478])lete
# tensor(3389, device='cuda:0')
# torch.Size([892136])lete
# tensor(4034, device='cuda:0')
# torch.Size([548178])lete
# tensor(2991, device='cuda:0')
# torch.Size([471615])lete
# tensor(2424, device='cuda:0')
# torch.Size([566257])lete
# tensor(2967, device='cuda:0')
# torch.Size([524276])lete
# tensor(2846, device='cuda:0')
# torch.Size([818702])lete
# tensor(3965, device='cuda:0')
# torch.Size([707099])lete
# tensor(3414, device='cuda:0')
# torch.Size([582750])lete
# tensor(2669, device='cuda:0')
# torch.Size([610515])lete
# tensor(3069, device='cuda:0')
# torch.Size([735533])lete
# tensor(3795, device='cuda:0')
# torch.Size([495365])lete
# tensor(2551, device='cuda:0')
# torch.Size([814309])lete
# tensor(3564, device='cuda:0')
# torch.Size([782153])lete
# tensor(3908, device='cuda:0')
# torch.Size([738485])lete
# tensor(3994, device='cuda:0')
# torch.Size([476775])lete
# tensor(2947, device='cuda:0')
# torch.Size([875999])lete
# tensor(3779, device='cuda:0')
# torch.Size([831838])lete
# tensor(3963, device='cuda:0')
# torch.Size([737163])lete
# tensor(3622, device='cuda:0')
# torch.Size([574940])lete
# tensor(3800, device='cuda:0')
# torch.Size([550293])lete
# tensor(2846, device='cuda:0')
# torch.Size([704151])lete
# tensor(3395, device='cuda:0')
# torch.Size([704339])lete
# tensor(3160, device='cuda:0')
# torch.Size([727605])lete
# tensor(3619, device='cuda:0')
# torch.Size([541083])lete
# tensor(3208, device='cuda:0')
# torch.Size([543255])lete
# tensor(2855, device='cuda:0')
# torch.Size([728849])lete
# tensor(3267, device='cuda:0')
# torch.Size([547746])lete
# tensor(2646, device='cuda:0')
# torch.Size([430470])lete
# tensor(1941, device='cuda:0')
# torch.Size([475406])lete
# tensor(2777, device='cuda:0')
# torch.Size([359099])lete
# tensor(1897, device='cuda:0')
# torch.Size([448813])lete
# tensor(2486, device='cuda:0')
# torch.Size([370805])lete
# tensor(2547, device='cuda:0')
# torch.Size([791181])lete
# tensor(3853, device='cuda:0')
# torch.Size([639839])lete
# tensor(3241, device='cuda:0')
# torch.Size([469147])lete
# tensor(2569, device='cuda:0')
# torch.Size([847772])lete
# tensor(4053, device='cuda:0')
# torch.Size([716128])lete
# tensor(3633, device='cuda:0')
# torch.Size([534489])lete
# tensor(2810, device='cuda:0')
# torch.Size([692715])lete
# tensor(3563, device='cuda:0')
# torch.Size([644238])lete
# tensor(3293, device='cuda:0')
# torch.Size([634821])lete
# tensor(2772, device='cuda:0')
# torch.Size([697807])lete
# tensor(3468, device='cuda:0')
# torch.Size([773124])lete
# tensor(3959, device='cuda:0')
# torch.Size([676226])lete
# tensor(3370, device='cuda:0')
# torch.Size([489059])lete
# tensor(2600, device='cuda:0')
# torch.Size([705302])lete
# tensor(2856, device='cuda:0')
# torch.Size([742128])lete
# tensor(3657, device='cuda:0')
# torch.Size([637301])lete
# tensor(3271, device='cuda:0')
# torch.Size([840083])lete
# tensor(3980, device='cuda:0')
# torch.Size([632992])lete
# tensor(3100, device='cuda:0')

# %% [markdown]
# ## Debug Dataloader

# %%
from torch.utils.data import Dataset, DataLoader

# %%
from LightningModules.Filter.utils import load_dataset

# %%
class filter_dataset(Dataset):
    
    def __init__(self, dataset, hparams):
        
        # Setup here
        self.dataset = dataset
        self.hparams = hparams
        
    def __len__(self):
        
        return len(self.dataset)
    
    def __getitem__(self, idx):
        
        batch = self.dataset[idx]
        print(batch)
        
        print(batch.edge_index.device)
        
        if "subset" in self.hparams["regime"]:
            subset_mask = np.isin(batch.edge_index, batch.modulewise_true_edges.unique()).any(0)
            batch.edge_index = batch.edge_index[:, subset_mask]
            batch.y = batch.y[subset_mask]
            
        if self.hparams["ratio"] != 0:
            num_true, num_false = batch.y.bool().sum(), (~batch.y.bool()).sum()
            
            fake_indices = torch.where(~batch.y.bool())[0]
            
            fake_indices = fake_indices[torch.randint(len(fake_indices), (num_true.item() * self.hparams["ratio"], ))]

            true_indices = torch.where(batch.y.bool())[0]
            combined_indices = torch.cat([true_indices, fake_indices])
            
            # Shuffle indices:
            combined_indices = combined_indices[torch.randperm(len(combined_indices))]
            
        else:
            combined_indices = torch.range(batch.edge_index.shape[1])
        
        return {"x": batch.x, "cell_data": batch.cell_data, "edge_index": batch.edge_index[:, combined_indices], "y": batch.y[combined_indices]}

# %%
input_dirs = [None, None, None]
input_dirs[: len(hparams["datatype_names"])] = [
            os.path.join(hparams["input_dir"], datatype)
            for datatype in hparams["datatype_names"]
        ]
trainset, valset, testset = [
            load_dataset(input_dir, hparams["datatype_split"][i])
            for i, input_dir in enumerate(input_dirs)
        ]

# %%
train_dataset = filter_dataset(trainset, hparams)

# %%
trainloader = DataLoader(train_dataset)

# %%
# %%time
for batch in trainloader:
    print(batch["edge_index"])
    break
# Out:
# Data(cell_data=[341982, 11], edge_index=[2, 101003780], event_file="/project/projectdirs/m3443/data/ITk-upgrade/processed/full_events_v4/event000000001", hid=[341982], modulewise_true_edges=[2, 105926], nhits=[341982], pid=[341982], primary=[341982], pt=[341982], x=[341982, 3], y=[101003780])
# cpu
# tensor([[[273383, 249188, 112490,  ..., 100450,   7873,  25971],
#          [ 72816, 249189, 147802,  ..., 101111,   7948,  25927]]])
# CPU times: user 1.57 s, sys: 1.39 s, total: 2.96 s
# Wall time: 2.05 s

# %%
# %%time
for batch in trainloader:
    print(batch["edge_index"])
    break
# Out:
# Data(cell_data=[341982, 11], edge_index=[2, 101003780], event_file="/project/projectdirs/m3443/data/ITk-upgrade/processed/full_events_v4/event000000001", hid=[341982], modulewise_true_edges=[2, 105926], nhits=[341982], pid=[341982], primary=[341982], pt=[341982], x=[341982, 3], y=[101003780])
# cpu
# tensor([[[158985, 179864, 105714,  ..., 133918,  86909,   7970],
#          [138949, 210452,  96479,  ..., 134260,  79507,   7905]]])
# CPU times: user 1.53 s, sys: 1.34 s, total: 2.86 s
# Wall time: 2.03 s

# %%
# %%time
print(train_dataset[1])
# Out:
# Data(cell_data=[273411, 11], edge_index=[2, 67594267], event_file="/project/projectdirs/m3443/data/ITk-upgrade/processed/full_events_v4/event000010002", hid=[273411], modulewise_true_edges=[2, 84055], nhits=[273411], pid=[273411], primary=[273411], pt=[273411], x=[273411, 3], y=[67594267])
# cpu
# ratio
# 1
# 2
# shuffle
# {'x': tensor([[ 0.0459, -0.8398, -0.2630],
#         [ 0.0380, -0.9124, -0.2630],
#         [ 0.0398, -0.8858, -0.2630],
#         ...,
#         [ 0.8879, -0.0572,  2.8542],
#         [ 0.9639, -0.0350,  2.8542],
#         [ 0.9285, -0.0371,  2.8542]]), 'edge_index': tensor([[ 91043,  88616,  24671,  ..., 201452, 261179,  56599],
#         [ 84328, 112683,  24734,  ..., 200540, 266407,  56667]]), 'y': tensor([ True, False,  True,  ..., False, False,  True])}
# CPU times: user 1.1 s, sys: 867 ms, total: 1.96 s
# Wall time: 1.37 s

# %% [markdown]
# ### Test metrics

# %%
all_efficiencies, all_purities = [], []
all_radius = np.arange(0.5, 1.2, 0.1)

with torch.no_grad():

    model.hparams.r_test = r
    test_results = trainer.test(ckpt_path=None)

    # Get eff, pur
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.29412952065467834,
#  'pur': 0.31158846616744995,
#  'val_loss': 0.8040090799331665}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.5026120543479919,
#  'pur': 0.3214113712310791,
#  'val_loss': 0.828713059425354}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.6482229828834534,
#  'pur': 0.2828279137611389,
#  'val_loss': 0.8727149963378906}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.745759904384613,
#  'pur': 0.23499229550361633,
#  'val_loss': 0.9117689728736877}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.8200681805610657,
#  'pur': 0.18902744352817535,
#  'val_loss': 0.9429423809051514}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.8717353343963623,
#  'pur': 0.15006624162197113,
#  'val_loss': 0.9644220471382141}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.9083821177482605,
#  'pur': 0.12099817395210266,
#  'val_loss': 0.9782997965812683}
# --------------------------------------------------------------------------------

# %%
eta_cuts = np.arange(-4, 4, 0.1)
pt_cuts = np.arange(1, 5, 0.5)

av_eta = test_results[""]
av_pt

for eta in eta_cuts

# %% [markdown]
# We should always visualise two important metrics: the efficiency (the number of true positives divided by the total number of possible true edges) and the purity (the number of true positives divided by the number of predicted edges). Is it clear to you why the graphs below behave as they do, as we widen the sphere around each hit to generate neighboring edges?

# %%
plt.figure(figsize=(12,8))
plt.plot(all_radius, all_efficiencies);
plt.title("Embedding efficiency", fontsize=24), plt.xlabel("Radius of neighborhood", fontsize=18), plt.ylabel("Efficiency", fontsize=18);

# %%
plt.figure(figsize=(12,8))
plt.plot(all_radius, all_purities);
plt.title("Embedding purity", fontsize=24), plt.xlabel("Radius of neighborhood", fontsize=18), plt.ylabel("Purity", fontsize=18);

# %% [markdown]
# ### Visualise embedding / latent space

# %% [markdown]
# Another useful thing to visualise is the actual space being embedded into. Since it's 8 dimensional, we can reduce it to 2 dimensions with "Principal Component Analysis".

# %%
from sklearn.decomposition import PCA

# %%
example_data = trainset[0]
particle_ids = example_data.pid
cyl_coords = example_data.x
cell_features = example_data.cell_data
all_features = torch.cat([cyl_coords, cell_features], axis=-1).to("cuda")

# %%
latent_features = model(all_features)

# %%
pca = PCA(n_components=2)

# %%
reduced_dimensions = pca.fit_transform(latent_features.detach().cpu())

# %%
reduced_dimensions
# Out:
# array([[-8.95513417, -3.68551328],
#        [-9.26373197, -2.57803677],
#        [17.49976278,  3.70361098],
#        ...,
#        [16.35837063, -5.6276739 ],
#        [17.72111695, -4.57634675],
#        [13.94139828, -8.52278351]])

# %%
plt.figure(figsize=(12,8))
plt.scatter(reduced_dimensions[:, 0], reduced_dimensions[:, 1], s=1)

# %% [markdown]
# The above plot is what **all** the data looks like in the latent space. Let's pick a (long) particle track and see if the track is projected to be close together:

# %%
particles, counts = np.unique(example_data.pid, return_counts=True)

# %%
example_particle = particles[counts > 10][0]

# %%
plt.figure(figsize=(12,8))
plt.scatter(reduced_dimensions[:, 0], reduced_dimensions[:, 1], s=1)
plt.scatter(reduced_dimensions[particle_ids == example_particle, 0], reduced_dimensions[particle_ids == example_particle, 1])

# %% [markdown]
# There are at least 10 hits in the plot above. Hopefully some of them cluster together into blobs, and that the blobs are close to other blobs of the same color. We get ~99% efficiency with this model, so even if some blobs appear far away in the PCA-reduced 2D space, they are most likely much closer in the 8-dimensional space. You can check this yourself!

# %% [markdown]
# ## Further Investigation

# %% [markdown]
# 1. Is there any performance gain from increasing the number of hidden channels?
# 2. What about *decreasing* the number of channels?
# 3. What about increasing/decreasing the number of dimensions in the latent space?
# 4. Is it possible to overtrain? That is, try increasing the number of epochs and seeing if the validation loss always decreases, plateaus, or starts to increase
# 5. Learning rate can be **everything** in some models. What effect does it have to increase/decrease it here?
# 6. Similarly, "warm-up" is like a slow start, where the learning rate increases for X batches (default of 100 here). Try changing it and seeing if you can improve the final performance.
# 7. To train the model here we use a combination of random pairs (that is, just picking pairs of hits at random, seeing if they belong to the same track, and

# %% [markdown]
# ## Follow up

# %%
save_dir = "/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val"

# %%
file_list = [os.path.join(save_dir, file) for file in os.listdir(save_dir)]

# %%
file_list
# Out:
# ['/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1415',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2447',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2280',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/0124',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2323',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2050',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2432',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1265',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1923',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2049',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1985',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1035',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2085',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/0194',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1263',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2167',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1344',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/1765',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2581',
#  '/project/projectdirs/m3443/data/ITk-upgrade/processed/filter_processed/1_GeV_unweighted_high_eff/val/2414']

# %%
graph_list = [torch.load(file, map_location=torch.device('cpu')) for file in file_list]

# %%
graph = graph_list[0]

# %%
graph.y.sum() / graph.y.shape[0]
# Out:
# tensor(0.0099)

# %%
graph.y.sum() / graph.modulewise_true_edges.shape[1]
# Out:
# tensor(0.9534)

# %%
np.mean([graph.y.sum() / graph.y.shape[0] for graph in graph_list]), np.std([graph.y.sum() / graph.y.shape[0] for graph in graph_list])
# Out:
# (0.010189917, 0.0011031473)

# %%
np.mean([graph.y.sum() / graph.modulewise_true_edges.shape[1] for graph in graph_list]), np.std([graph.y.sum() / graph.modulewise_true_edges.shape[1] for graph in graph_list])
# Out:
# (0.9542246, 0.0041688033)

# %%
np.mean([graph.edge_index.shape[1] for graph in graph_list]), np.std([graph.edge_index.shape[1] for graph in graph_list])
# Out:
# (1259807.35, 262131.71836335925)
