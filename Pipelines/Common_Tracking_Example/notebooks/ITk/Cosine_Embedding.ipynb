# %% [markdown]
# # Example of Metric Learning in Embedded Space

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# System imports
import os
import sys
import yaml

# External imports
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.decomposition import PCA
from sklearn.metrics import auc
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from pytorch_lightning.loggers import TensorBoardLogger, WandbLogger
from pytorch_lightning import Trainer
import frnn

sys.path.append('../..')

from LightningModules.Embedding.Models.cosine_layerless_embedding import CosineLayerlessEmbedding
import copy
from LightningModules.Embedding.utils import multi_build_edges, graph_intersection

device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Pytorch Lightning Model

# %% [markdown]
# In this example notebook, we will use an approach to ML called Pytorch Lightning. Pytorch is a library like Tensorflow, which is very popular in ML engineering. It's main appeal is foolproof tracking of gradients for backpropagation, and very easy manipulation of tensors on and off GPUs.
#
# Pytorch Lightning is an extension of Pytorch that makes some decisions about the best-practices for training. Instead of you writing the training loop yourself, and moving things on and off a GPU, it handles much of this for you. You write all the data loading logic, the loss functions, etc. into a `LightningModule` and then hand this module to a `Trainer`. Together, the module and trainer are the two objects that allow training and inference.

# %% [markdown]
# So we start by importing a class that we have written ourselves, in this case a LightningModule that is in charge of loading TrackML (Codalab) data, and training and validating an embedding/metric learning model.

# %% [markdown]
# ### Construct PyLightning model

# %% [markdown]
# An ML model typically has many knobs to turn, as well as locations of data, some training preferences, and so on. For convenience, let's put all of these parameters into a YAML file and load it.

# %%
with open("Cosine_embedding.yaml") as f:
        hparams = yaml.load(f, Loader=yaml.FullLoader)
# Out:
# {'input_dir': '/global/cfs/cdirs/m3443/data/ITk-upgrade/processed/feature_store/feature_store_modulewise_v2', 'project': 'ITk_1GeV', 'train_split': [1000, 10, 0], 'true_edges': 'modulewise_true_edges', 'noise': True, 'train_on_noise': False, 'spatial_channels': 3, 'cell_channels': 8, 'emb_hidden': 1024, 'n_spaces': 1, 'nb_shared_layer': 5, 'nb_independent_layer': 1, 'emb_dim': 8, 'weight': 10, 'randomisation': 1, 'signal_points_per_batch': 100000, 'noise_points_per_batch': 100000, 'r_train': 1.0, 'r_val': 1.0, 'r_test': 1.5, 'knn': 60, 'warmup': 1000, 'margin': 0.5, 'lr': 0.0005, 'factor': 0.3, 'patience': 15, 'regime': ['rp', 'ci', 'hnm'], 'max_epochs': 50, 'val_noise_cut': 0.5, 'cluster_loss_weight': 1, 'callbacks': 'EmbeddingTelemetry', 'wandb_save_dir': '/global/homes/r/ryanliu/ExaTrkX/wandb_data'}

# %% [markdown]
# We plug these parameters into a constructor of the `LayerlessEmbedding` Lightning Module. This doesn't **do** anything yet - merely creates the object.

# %%
model = CosineLayerlessEmbedding(hparams)
checkpoint = torch.load("/global/cfs/cdirs/m3443/usr/ryanliu/ITk_embedding/ITk_0.5GeV/9508spbw/checkpoints/epoch=3-step=3999.ckpt")
model.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Metric Learning

# %% [markdown]
# ### Train embedding

# %% [markdown]
# Finally! Let's train! We instantiate a `Trainer` class that knows things like which hardware to work with, how long to train for, and a **bunch** of default options that we ignore here. Check out the Trainer class docs in Pytorch Lightning. Suffice it to say that it clears away much repetitive boilerplate in training code.

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    monitor='eff',
    mode="max",
    save_top_k=2,
    save_last=True)

# %%
logger = WandbLogger(project="ITk_0GeV", group="Common_track_cosine_embedding")
trainer = Trainer(gpus=1, max_epochs=hparams["max_epochs"], logger=logger, num_sanity_val_steps=0, callbacks=[checkpoint_callback], default_root_dir="/global/cfs/cdirs/m3443/usr/ryanliu/ITk_embedding/")
trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /global/homes/r/ryanliu/.conda/envs/gnn/lib/python3.8/site-packages/pytorch_lightning/loggers/wandb.py:341: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
#
#   | Name            | Type             | Params
# -----------------------------------------------------
# 0 | cos             | CosineSimilarity | 0
# 1 | layers          | ModuleList       | 4.2 M
# 2 | n_spaces_layers | ModuleList       | 8.2 K
# 3 | act             | GELU             | 0
# -----------------------------------------------------
# 4.2 M     Trainable params
# 0         Non-trainable params
# 4.2 M     Total params
# 16.876    Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1010 [00:00<?, ?it/s] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   0%|          | 1/1010 [00:01<21:11,  1.26s/it, loss=0.47, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   0%|          | 2/1010 [00:01<13:17,  1.26it/s, loss=0.471, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   0%|          | 3/1010 [00:01<11:02,  1.52it/s, loss=0.47, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   0%|          | 4/1010 [00:02<09:35,  1.75it/s, loss=0.472, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   0%|          | 5/1010 [00:02<08:57,  1.87it/s, loss=0.472, v_num=nt6u]tensor([5., 4., 4.], device='cuda:0')
# Epoch 0:   1%|          | 6/1010 [00:02<08:18,  2.01it/s, loss=0.472, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|          | 7/1010 [00:03<08:02,  2.08it/s, loss=0.471, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|          | 8/1010 [00:03<07:39,  2.18it/s, loss=0.471, v_num=nt6u]tensor([5., 5., 4.], device='cuda:0')
# Epoch 0:   1%|          | 9/1010 [00:03<07:20,  2.27it/s, loss=0.471, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|          | 10/1010 [00:04<07:07,  2.34it/s, loss=0.471, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|          | 11/1010 [00:04<07:01,  2.37it/s, loss=0.471, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|          | 12/1010 [00:05<06:56,  2.40it/s, loss=0.47, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|▏         | 13/1010 [00:05<06:48,  2.44it/s, loss=0.47, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|▏         | 14/1010 [00:05<06:42,  2.47it/s, loss=0.47, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   1%|▏         | 15/1010 [00:06<06:38,  2.50it/s, loss=0.47, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 16/1010 [00:06<06:31,  2.54it/s, loss=0.47, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 17/1010 [00:06<06:28,  2.56it/s, loss=0.469, v_num=nt6u]tensor([4., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 18/1010 [00:06<06:22,  2.60it/s, loss=0.47, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 19/1010 [00:07<06:16,  2.64it/s, loss=0.47, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 20/1010 [00:07<06:12,  2.66it/s, loss=0.469, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 21/1010 [00:07<06:12,  2.65it/s, loss=0.469, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 22/1010 [00:08<06:08,  2.68it/s, loss=0.468, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 23/1010 [00:08<06:03,  2.71it/s, loss=0.468, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 24/1010 [00:08<06:00,  2.73it/s, loss=0.467, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   2%|▏         | 25/1010 [00:09<05:58,  2.75it/s, loss=0.467, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 26/1010 [00:09<05:54,  2.77it/s, loss=0.466, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 27/1010 [00:09<05:54,  2.77it/s, loss=0.466, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 28/1010 [00:10<05:51,  2.80it/s, loss=0.465, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 29/1010 [00:10<05:51,  2.79it/s, loss=0.465, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 30/1010 [00:10<05:50,  2.80it/s, loss=0.464, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 31/1010 [00:11<05:47,  2.82it/s, loss=0.464, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 32/1010 [00:11<05:47,  2.82it/s, loss=0.463, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 33/1010 [00:11<05:45,  2.83it/s, loss=0.462, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 34/1010 [00:11<05:44,  2.84it/s, loss=0.462, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   3%|▎         | 35/1010 [00:12<05:41,  2.85it/s, loss=0.461, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▎         | 36/1010 [00:12<05:41,  2.85it/s, loss=0.46, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▎         | 37/1010 [00:12<05:41,  2.85it/s, loss=0.459, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 38/1010 [00:13<05:39,  2.86it/s, loss=0.458, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 39/1010 [00:13<05:38,  2.87it/s, loss=0.457, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 40/1010 [00:13<05:38,  2.87it/s, loss=0.456, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 41/1010 [00:14<05:35,  2.89it/s, loss=0.456, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 42/1010 [00:14<05:34,  2.89it/s, loss=0.455, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 43/1010 [00:14<05:33,  2.90it/s, loss=0.454, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 44/1010 [00:15<05:31,  2.91it/s, loss=0.453, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   4%|▍         | 45/1010 [00:15<05:31,  2.91it/s, loss=0.452, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▍         | 46/1010 [00:15<05:29,  2.92it/s, loss=0.451, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▍         | 47/1010 [00:16<05:29,  2.92it/s, loss=0.45, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▍         | 48/1010 [00:16<05:27,  2.93it/s, loss=0.449, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▍         | 49/1010 [00:16<05:28,  2.92it/s, loss=0.448, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▍         | 50/1010 [00:17<05:27,  2.94it/s, loss=0.447, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▌         | 51/1010 [00:17<05:26,  2.94it/s, loss=0.446, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▌         | 52/1010 [00:17<05:25,  2.94it/s, loss=0.445, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▌         | 53/1010 [00:17<05:25,  2.94it/s, loss=0.444, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▌         | 54/1010 [00:18<05:25,  2.94it/s, loss=0.443, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   5%|▌         | 55/1010 [00:18<05:24,  2.94it/s, loss=0.442, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 56/1010 [00:18<05:23,  2.95it/s, loss=0.441, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 57/1010 [00:19<05:22,  2.95it/s, loss=0.44, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 58/1010 [00:19<05:21,  2.96it/s, loss=0.439, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 59/1010 [00:19<05:21,  2.96it/s, loss=0.438, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 60/1010 [00:20<05:20,  2.96it/s, loss=0.437, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 61/1010 [00:20<05:20,  2.96it/s, loss=0.436, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 62/1010 [00:20<05:20,  2.95it/s, loss=0.435, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▌         | 63/1010 [00:21<05:19,  2.96it/s, loss=0.434, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▋         | 64/1010 [00:21<05:19,  2.96it/s, loss=0.433, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   6%|▋         | 65/1010 [00:21<05:18,  2.97it/s, loss=0.432, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 66/1010 [00:22<05:18,  2.96it/s, loss=0.431, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 67/1010 [00:22<05:18,  2.96it/s, loss=0.43, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 68/1010 [00:22<05:17,  2.97it/s, loss=0.429, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 69/1010 [00:23<05:16,  2.97it/s, loss=0.428, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 70/1010 [00:23<05:16,  2.97it/s, loss=0.427, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 71/1010 [00:23<05:16,  2.97it/s, loss=0.427, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 72/1010 [00:24<05:16,  2.96it/s, loss=0.426, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 73/1010 [00:24<05:16,  2.96it/s, loss=0.425, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 74/1010 [00:24<05:16,  2.96it/s, loss=0.424, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   7%|▋         | 75/1010 [00:25<05:15,  2.97it/s, loss=0.423, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 76/1010 [00:25<05:14,  2.97it/s, loss=0.422, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 77/1010 [00:25<05:14,  2.97it/s, loss=0.422, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 78/1010 [00:26<05:14,  2.97it/s, loss=0.421, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 79/1010 [00:26<05:13,  2.97it/s, loss=0.42, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 80/1010 [00:27<05:13,  2.96it/s, loss=0.42, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 81/1010 [00:27<05:14,  2.96it/s, loss=0.419, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 82/1010 [00:27<05:14,  2.95it/s, loss=0.418, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 83/1010 [00:28<05:13,  2.96it/s, loss=0.418, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 84/1010 [00:28<05:13,  2.96it/s, loss=0.417, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   8%|▊         | 85/1010 [00:28<05:13,  2.95it/s, loss=0.416, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▊         | 86/1010 [00:29<05:13,  2.95it/s, loss=0.416, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▊         | 87/1010 [00:29<05:13,  2.95it/s, loss=0.415, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▊         | 88/1010 [00:29<05:12,  2.95it/s, loss=0.415, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▉         | 89/1010 [00:30<05:12,  2.95it/s, loss=0.414, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▉         | 90/1010 [00:30<05:11,  2.96it/s, loss=0.414, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▉         | 91/1010 [00:30<05:10,  2.96it/s, loss=0.413, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▉         | 92/1010 [00:31<05:10,  2.95it/s, loss=0.413, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▉         | 93/1010 [00:31<05:11,  2.95it/s, loss=0.412, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▉         | 94/1010 [00:31<05:11,  2.94it/s, loss=0.412, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:   9%|▉         | 95/1010 [00:32<05:10,  2.94it/s, loss=0.412, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|▉         | 96/1010 [00:32<05:11,  2.94it/s, loss=0.411, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|▉         | 97/1010 [00:33<05:11,  2.93it/s, loss=0.411, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|▉         | 98/1010 [00:33<05:11,  2.93it/s, loss=0.411, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|▉         | 99/1010 [00:33<05:11,  2.93it/s, loss=0.41, v_num=nt6u] tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|▉         | 100/1010 [00:34<05:11,  2.92it/s, loss=0.41, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|█         | 101/1010 [00:34<05:11,  2.92it/s, loss=0.41, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|█         | 102/1010 [00:34<05:11,  2.91it/s, loss=0.409, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|█         | 103/1010 [00:35<05:10,  2.92it/s, loss=0.409, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|█         | 104/1010 [00:35<05:11,  2.91it/s, loss=0.409, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|█         | 105/1010 [00:36<05:10,  2.91it/s, loss=0.409, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  10%|█         | 106/1010 [00:36<05:10,  2.91it/s, loss=0.408, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█         | 107/1010 [00:36<05:10,  2.91it/s, loss=0.408, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█         | 108/1010 [00:37<05:10,  2.91it/s, loss=0.408, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█         | 109/1010 [00:37<05:09,  2.91it/s, loss=0.408, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█         | 110/1010 [00:37<05:09,  2.91it/s, loss=0.407, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█         | 111/1010 [00:38<05:09,  2.90it/s, loss=0.407, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█         | 112/1010 [00:38<05:09,  2.90it/s, loss=0.407, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█         | 113/1010 [00:39<05:09,  2.90it/s, loss=0.407, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█▏        | 114/1010 [00:39<05:09,  2.90it/s, loss=0.406, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█▏        | 115/1010 [00:39<05:08,  2.90it/s, loss=0.406, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  11%|█▏        | 116/1010 [00:40<05:08,  2.90it/s, loss=0.406, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 117/1010 [00:40<05:08,  2.90it/s, loss=0.406, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 118/1010 [00:40<05:07,  2.90it/s, loss=0.406, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 119/1010 [00:41<05:07,  2.89it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 120/1010 [00:41<05:07,  2.90it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 121/1010 [00:41<05:06,  2.90it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 122/1010 [00:42<05:06,  2.90it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 123/1010 [00:42<05:06,  2.90it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 124/1010 [00:42<05:06,  2.89it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 125/1010 [00:43<05:06,  2.89it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  12%|█▏        | 126/1010 [00:43<05:05,  2.89it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 127/1010 [00:43<05:05,  2.89it/s, loss=0.405, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 128/1010 [00:44<05:04,  2.89it/s, loss=0.404, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 129/1010 [00:44<05:04,  2.89it/s, loss=0.404, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 130/1010 [00:45<05:04,  2.89it/s, loss=0.404, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 131/1010 [00:45<05:04,  2.89it/s, loss=0.404, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 132/1010 [00:45<05:04,  2.88it/s, loss=0.404, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 133/1010 [00:46<05:04,  2.88it/s, loss=0.404, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 134/1010 [00:46<05:04,  2.88it/s, loss=0.404, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 135/1010 [00:47<05:04,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  13%|█▎        | 136/1010 [00:47<05:04,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▎        | 137/1010 [00:47<05:03,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▎        | 138/1010 [00:48<05:03,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 139/1010 [00:48<05:03,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 140/1010 [00:48<05:03,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 141/1010 [00:49<05:03,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 142/1010 [00:49<05:02,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 143/1010 [00:49<05:02,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 144/1010 [00:50<05:01,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 145/1010 [00:50<05:01,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  14%|█▍        | 146/1010 [00:50<05:00,  2.87it/s, loss=0.403, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▍        | 147/1010 [00:51<05:01,  2.87it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▍        | 148/1010 [00:51<05:00,  2.87it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▍        | 149/1010 [00:51<05:00,  2.87it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▍        | 150/1010 [00:52<04:59,  2.87it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▍        | 151/1010 [00:52<04:59,  2.87it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▌        | 152/1010 [00:53<04:59,  2.87it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▌        | 153/1010 [00:53<04:59,  2.87it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▌        | 154/1010 [00:53<04:59,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▌        | 155/1010 [00:54<04:59,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  15%|█▌        | 156/1010 [00:54<04:58,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 157/1010 [00:54<04:58,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 158/1010 [00:55<04:57,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 159/1010 [00:55<04:57,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 160/1010 [00:55<04:57,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 161/1010 [00:56<04:56,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 162/1010 [00:56<04:56,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 163/1010 [00:57<04:56,  2.86it/s, loss=0.402, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▌        | 164/1010 [00:57<04:56,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▋        | 165/1010 [00:57<04:56,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  16%|█▋        | 166/1010 [00:58<04:56,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 167/1010 [00:58<04:55,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 168/1010 [00:58<04:55,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 169/1010 [00:59<04:55,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 170/1010 [00:59<04:54,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 171/1010 [01:00<04:54,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 172/1010 [01:00<04:54,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 173/1010 [01:00<04:53,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 174/1010 [01:01<04:53,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 175/1010 [01:01<04:53,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  17%|█▋        | 176/1010 [01:01<04:52,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 177/1010 [01:02<04:52,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 178/1010 [01:02<04:52,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 179/1010 [01:02<04:52,  2.85it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 180/1010 [01:03<04:52,  2.84it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 181/1010 [01:04<04:53,  2.83it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 182/1010 [01:04<04:52,  2.83it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 183/1010 [01:04<04:52,  2.83it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 184/1010 [01:05<04:52,  2.83it/s, loss=0.401, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 185/1010 [01:05<04:51,  2.83it/s, loss=0.4, v_num=nt6u]  tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  18%|█▊        | 186/1010 [01:05<04:51,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▊        | 187/1010 [01:06<04:50,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▊        | 188/1010 [01:06<04:50,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▊        | 189/1010 [01:06<04:50,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▉        | 190/1010 [01:07<04:49,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▉        | 191/1010 [01:07<04:49,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▉        | 192/1010 [01:07<04:49,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▉        | 193/1010 [01:08<04:48,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▉        | 194/1010 [01:08<04:48,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▉        | 195/1010 [01:08<04:48,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  19%|█▉        | 196/1010 [01:09<04:47,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|█▉        | 197/1010 [01:09<04:47,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|█▉        | 198/1010 [01:09<04:46,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|█▉        | 199/1010 [01:10<04:46,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|█▉        | 200/1010 [01:10<04:46,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|█▉        | 201/1010 [01:11<04:46,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|██        | 202/1010 [01:11<04:45,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|██        | 203/1010 [01:11<04:45,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|██        | 204/1010 [01:12<04:45,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|██        | 205/1010 [01:12<04:45,  2.82it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|██        | 206/1010 [01:12<04:44,  2.82it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  20%|██        | 207/1010 [01:13<04:44,  2.82it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██        | 208/1010 [01:13<04:43,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██        | 209/1010 [01:13<04:43,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██        | 210/1010 [01:14<04:42,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██        | 211/1010 [01:14<04:42,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██        | 212/1010 [01:14<04:42,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██        | 213/1010 [01:15<04:41,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██        | 214/1010 [01:15<04:41,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██▏       | 215/1010 [01:16<04:41,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██▏       | 216/1010 [01:16<04:41,  2.82it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  21%|██▏       | 217/1010 [01:16<04:40,  2.82it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 218/1010 [01:17<04:40,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 219/1010 [01:17<04:39,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 220/1010 [01:17<04:39,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 221/1010 [01:18<04:39,  2.83it/s, loss=0.4, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 222/1010 [01:18<04:38,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 223/1010 [01:18<04:38,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 224/1010 [01:19<04:38,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 225/1010 [01:19<04:37,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 226/1010 [01:20<04:37,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  22%|██▏       | 227/1010 [01:20<04:37,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 228/1010 [01:20<04:37,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 229/1010 [01:21<04:36,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 230/1010 [01:21<04:36,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 231/1010 [01:21<04:36,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 232/1010 [01:22<04:35,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 233/1010 [01:22<04:35,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 234/1010 [01:22<04:34,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 235/1010 [01:23<04:34,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 236/1010 [01:23<04:34,  2.82it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  23%|██▎       | 237/1010 [01:23<04:33,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▎       | 238/1010 [01:24<04:32,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▎       | 239/1010 [01:24<04:32,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 240/1010 [01:24<04:32,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 241/1010 [01:25<04:31,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 242/1010 [01:25<04:31,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 243/1010 [01:26<04:31,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 244/1010 [01:26<04:31,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 245/1010 [01:26<04:30,  2.83it/s, loss=0.399, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 246/1010 [01:27<04:30,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  24%|██▍       | 247/1010 [01:27<04:29,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▍       | 248/1010 [01:27<04:29,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▍       | 249/1010 [01:28<04:29,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▍       | 250/1010 [01:28<04:28,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▍       | 251/1010 [01:28<04:28,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▍       | 252/1010 [01:29<04:28,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▌       | 253/1010 [01:29<04:27,  2.83it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▌       | 254/1010 [01:29<04:27,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▌       | 255/1010 [01:30<04:27,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▌       | 256/1010 [01:30<04:27,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  25%|██▌       | 257/1010 [01:31<04:26,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 258/1010 [01:31<04:26,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 259/1010 [01:31<04:26,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 260/1010 [01:32<04:25,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 261/1010 [01:32<04:25,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 262/1010 [01:32<04:25,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 263/1010 [01:33<04:24,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 264/1010 [01:33<04:24,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▌       | 265/1010 [01:33<04:24,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▋       | 266/1010 [01:34<04:23,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  26%|██▋       | 267/1010 [01:34<04:23,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 268/1010 [01:35<04:23,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 269/1010 [01:35<04:23,  2.81it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 270/1010 [01:35<04:22,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 271/1010 [01:36<04:22,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 272/1010 [01:36<04:21,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 273/1010 [01:36<04:21,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 274/1010 [01:37<04:21,  2.81it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 275/1010 [01:37<04:21,  2.81it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 276/1010 [01:38<04:20,  2.81it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  27%|██▋       | 277/1010 [01:38<04:20,  2.82it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 278/1010 [01:38<04:20,  2.81it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 279/1010 [01:39<04:20,  2.81it/s, loss=0.398, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 280/1010 [01:39<04:19,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 281/1010 [01:39<04:19,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 282/1010 [01:40<04:18,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 283/1010 [01:40<04:18,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 284/1010 [01:40<04:18,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 285/1010 [01:41<04:17,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 286/1010 [01:41<04:17,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  28%|██▊       | 287/1010 [01:42<04:16,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▊       | 288/1010 [01:42<04:16,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▊       | 289/1010 [01:42<04:16,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▊       | 290/1010 [01:43<04:16,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▉       | 291/1010 [01:43<04:15,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▉       | 292/1010 [01:43<04:15,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▉       | 293/1010 [01:44<04:15,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▉       | 294/1010 [01:44<04:15,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▉       | 295/1010 [01:45<04:14,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▉       | 296/1010 [01:45<04:14,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  29%|██▉       | 297/1010 [01:45<04:13,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|██▉       | 298/1010 [01:46<04:13,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|██▉       | 299/1010 [01:46<04:13,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|██▉       | 300/1010 [01:46<04:13,  2.80it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|██▉       | 301/1010 [01:47<04:12,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|██▉       | 302/1010 [01:47<04:12,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|███       | 303/1010 [01:47<04:11,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|███       | 304/1010 [01:48<04:11,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|███       | 305/1010 [01:48<04:11,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|███       | 306/1010 [01:49<04:10,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|███       | 307/1010 [01:49<04:10,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  30%|███       | 308/1010 [01:49<04:10,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  31%|███       | 309/1010 [01:50<04:09,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  31%|███       | 310/1010 [01:50<04:09,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  31%|███       | 311/1010 [01:50<04:09,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  31%|███       | 312/1010 [01:51<04:08,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  31%|███       | 313/1010 [01:51<04:08,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  31%|███       | 314/1010 [01:51<04:07,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  31%|███       | 315/1010 [01:52<04:07,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  31%|███▏      | 316/1010 [01:52<04:07,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  31%|███▏      | 317/1010 [01:52<04:06,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  31%|███▏      | 318/1010 [01:53<04:06,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 319/1010 [01:53<04:06,  2.81it/s, loss=0.397, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 320/1010 [01:54<04:05,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 321/1010 [01:54<04:05,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 322/1010 [01:54<04:05,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 323/1010 [01:55<04:04,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 324/1010 [01:55<04:04,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 325/1010 [01:55<04:04,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 326/1010 [01:56<04:03,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 327/1010 [01:56<04:03,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  32%|███▏      | 328/1010 [01:56<04:02,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 329/1010 [01:57<04:02,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 330/1010 [01:57<04:02,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 331/1010 [01:57<04:01,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 332/1010 [01:58<04:01,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 333/1010 [01:58<04:01,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 334/1010 [01:58<04:00,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 335/1010 [01:59<04:00,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 336/1010 [01:59<04:00,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 337/1010 [02:00<03:59,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  33%|███▎      | 338/1010 [02:00<03:59,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  34%|███▎      | 339/1010 [02:00<03:59,  2.81it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  34%|███▎      | 340/1010 [02:01<03:58,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 341/1010 [02:01<03:58,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 342/1010 [02:02<03:58,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 343/1010 [02:02<03:57,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 344/1010 [02:02<03:57,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 345/1010 [02:03<03:57,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 346/1010 [02:03<03:56,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 347/1010 [02:03<03:56,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  34%|███▍      | 348/1010 [02:04<03:56,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  35%|███▍      | 349/1010 [02:04<03:55,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  35%|███▍      | 350/1010 [02:04<03:55,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  35%|███▍      | 351/1010 [02:05<03:55,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  35%|███▍      | 352/1010 [02:05<03:54,  2.80it/s, loss=0.396, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  35%|███▍      | 353/1010 [02:06<03:54,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  35%|███▌      | 354/1010 [02:06<03:54,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  35%|███▌      | 355/1010 [02:06<03:53,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  35%|███▌      | 356/1010 [02:07<03:53,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  35%|███▌      | 357/1010 [02:07<03:53,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  35%|███▌      | 358/1010 [02:07<03:52,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 359/1010 [02:08<03:52,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 360/1010 [02:08<03:51,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 361/1010 [02:08<03:51,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 362/1010 [02:09<03:51,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 363/1010 [02:09<03:50,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 364/1010 [02:09<03:50,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 365/1010 [02:10<03:50,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▌      | 366/1010 [02:10<03:49,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▋      | 367/1010 [02:10<03:49,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  36%|███▋      | 368/1010 [02:11<03:49,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 369/1010 [02:11<03:48,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 370/1010 [02:11<03:48,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 371/1010 [02:12<03:47,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 372/1010 [02:12<03:47,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 373/1010 [02:13<03:47,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 374/1010 [02:13<03:46,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 375/1010 [02:13<03:46,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 376/1010 [02:14<03:46,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 377/1010 [02:14<03:45,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  37%|███▋      | 378/1010 [02:14<03:45,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 379/1010 [02:15<03:44,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 380/1010 [02:15<03:44,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 381/1010 [02:15<03:44,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 382/1010 [02:16<03:43,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 383/1010 [02:16<03:43,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 384/1010 [02:16<03:43,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 385/1010 [02:17<03:42,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 386/1010 [02:17<03:42,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 387/1010 [02:17<03:42,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  38%|███▊      | 388/1010 [02:18<03:41,  2.81it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 0:  39%|███▊      | 389/1010 [02:18<03:41,  2.80it/s, loss=0.395, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# ...
# Epoch 3:  58%|█████▊    | 587/1010 [03:01<02:11,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  58%|█████▊    | 588/1010 [03:02<02:10,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  58%|█████▊    | 589/1010 [03:02<02:10,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  58%|█████▊    | 590/1010 [03:02<02:10,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▊    | 591/1010 [03:03<02:09,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▊    | 592/1010 [03:03<02:09,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▊    | 593/1010 [03:03<02:09,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▉    | 594/1010 [03:04<02:08,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  59%|█████▉    | 595/1010 [03:04<02:08,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▉    | 596/1010 [03:04<02:08,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▉    | 597/1010 [03:04<02:07,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▉    | 598/1010 [03:05<02:07,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  59%|█████▉    | 599/1010 [03:05<02:07,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  59%|█████▉    | 600/1010 [03:05<02:07,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|█████▉    | 601/1010 [03:06<02:06,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|█████▉    | 602/1010 [03:06<02:06,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|█████▉    | 603/1010 [03:06<02:06,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  60%|█████▉    | 604/1010 [03:07<02:05,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|█████▉    | 605/1010 [03:07<02:05,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|██████    | 606/1010 [03:07<02:05,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|██████    | 607/1010 [03:08<02:04,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|██████    | 608/1010 [03:08<02:04,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|██████    | 609/1010 [03:08<02:04,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|██████    | 610/1010 [03:09<02:03,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  60%|██████    | 611/1010 [03:09<02:03,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████    | 612/1010 [03:09<02:03,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████    | 613/1010 [03:09<02:03,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████    | 614/1010 [03:10<02:02,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████    | 615/1010 [03:10<02:02,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████    | 616/1010 [03:10<02:02,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████    | 617/1010 [03:11<02:01,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████    | 618/1010 [03:11<02:01,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████▏   | 619/1010 [03:11<02:01,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████▏   | 620/1010 [03:12<02:00,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  61%|██████▏   | 621/1010 [03:12<02:00,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 622/1010 [03:12<02:00,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 623/1010 [03:13<01:59,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 624/1010 [03:13<01:59,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 625/1010 [03:13<01:59,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 626/1010 [03:14<01:59,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 627/1010 [03:14<01:58,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 628/1010 [03:14<01:58,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 629/1010 [03:15<01:58,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 630/1010 [03:15<01:57,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  62%|██████▏   | 631/1010 [03:15<01:57,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 632/1010 [03:16<01:57,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 633/1010 [03:16<01:56,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 634/1010 [03:16<01:56,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 635/1010 [03:16<01:56,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 636/1010 [03:17<01:56,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 637/1010 [03:17<01:55,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 638/1010 [03:17<01:55,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 639/1010 [03:18<01:55,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 640/1010 [03:18<01:54,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  63%|██████▎   | 641/1010 [03:18<01:54,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  64%|██████▎   | 642/1010 [03:19<01:54,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  64%|██████▎   | 643/1010 [03:19<01:53,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 644/1010 [03:19<01:53,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 645/1010 [03:20<01:53,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 646/1010 [03:20<01:52,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 647/1010 [03:20<01:52,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 648/1010 [03:21<01:52,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 649/1010 [03:21<01:52,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 650/1010 [03:21<01:51,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  64%|██████▍   | 651/1010 [03:21<01:51,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▍   | 652/1010 [03:22<01:51,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▍   | 653/1010 [03:22<01:50,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▍   | 654/1010 [03:22<01:50,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▍   | 655/1010 [03:23<01:50,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▍   | 656/1010 [03:23<01:49,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▌   | 657/1010 [03:23<01:49,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▌   | 658/1010 [03:24<01:49,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▌   | 659/1010 [03:24<01:48,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▌   | 660/1010 [03:24<01:48,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  65%|██████▌   | 661/1010 [03:25<01:48,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 662/1010 [03:25<01:47,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 663/1010 [03:25<01:47,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 664/1010 [03:25<01:47,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 665/1010 [03:26<01:47,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 666/1010 [03:26<01:46,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 667/1010 [03:26<01:46,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 668/1010 [03:27<01:46,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▌   | 669/1010 [03:27<01:45,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▋   | 670/1010 [03:27<01:45,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  66%|██████▋   | 671/1010 [03:28<01:45,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 672/1010 [03:28<01:44,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 673/1010 [03:28<01:44,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 674/1010 [03:29<01:44,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 675/1010 [03:29<01:43,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 676/1010 [03:29<01:43,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 677/1010 [03:29<01:43,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 678/1010 [03:30<01:42,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 679/1010 [03:30<01:42,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 680/1010 [03:30<01:42,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  67%|██████▋   | 681/1010 [03:31<01:41,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 682/1010 [03:31<01:41,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 683/1010 [03:31<01:41,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 684/1010 [03:32<01:41,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 685/1010 [03:32<01:40,  3.22it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 686/1010 [03:32<01:40,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 687/1010 [03:33<01:40,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 688/1010 [03:33<01:39,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 689/1010 [03:33<01:39,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 690/1010 [03:33<01:39,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  68%|██████▊   | 691/1010 [03:34<01:38,  3.23it/s, loss=0.387, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▊   | 692/1010 [03:34<01:38,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▊   | 693/1010 [03:34<01:38,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▊   | 694/1010 [03:35<01:37,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  69%|██████▉   | 695/1010 [03:35<01:37,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▉   | 696/1010 [03:35<01:37,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▉   | 697/1010 [03:36<01:37,  3.23it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▉   | 698/1010 [03:36<01:36,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  69%|██████▉   | 699/1010 [03:36<01:36,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▉   | 700/1010 [03:37<01:36,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  69%|██████▉   | 701/1010 [03:37<01:35,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|██████▉   | 702/1010 [03:37<01:35,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|██████▉   | 703/1010 [03:38<01:35,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|██████▉   | 704/1010 [03:38<01:34,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|██████▉   | 705/1010 [03:38<01:34,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|██████▉   | 706/1010 [03:38<01:34,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|███████   | 707/1010 [03:39<01:33,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|███████   | 708/1010 [03:39<01:33,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|███████   | 709/1010 [03:39<01:33,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|███████   | 710/1010 [03:40<01:33,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  70%|███████   | 711/1010 [03:40<01:32,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 4., 5.], device='cuda:0')
# Epoch 3:  70%|███████   | 712/1010 [03:40<01:32,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  71%|███████   | 713/1010 [03:41<01:32,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  71%|███████   | 714/1010 [03:41<01:31,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  71%|███████   | 715/1010 [03:41<01:31,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  71%|███████   | 716/1010 [03:42<01:31,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  71%|███████   | 717/1010 [03:42<01:30,  3.22it/s, loss=0.386, v_num=nt6u]tensor([5., 5., 5.], device='cuda:0')
# Epoch 3:  71%|███████   | 718/1010 [03:42<01:30,  3.22it/s, loss=0.386, v_num=nt6u]

# %% [markdown]
# ### Test embedding

# %% [markdown]
# A Pytorch Lightning Trainer has two main methods: `fit` and `test`. They represent the two main steps of any ML engingeering or research: Train a model, then make sure it can infer accurately on test (i.e. **hidden**) data.

# %% [markdown]
# Note that `ckpt_path` just tells the trainer to use the latest "checkpoint" of the model, rather than *best* checkpoint. A checkpoint is a saved version of the model, a snapshot at a particular stage of the training process. Pytorch Lightning automatically saves a checkpoint of your model in case something crashes and we need to resume.

# %%
test_results = trainer.test(ckpt_path=None)

# %% [markdown]
# ## Performance

# %%
from LightningModules.Embedding.utils import get_metrics

# %% [markdown]
# Let's see how well the model learned to embed the hits into a space that separates them into discrete clusters. As in the data visualisation above, we are going manual here. So one thing we need to do is tell the model that we are **evaluating**, not **training**, with `model.eval()`. We also make sure to wrap everything with `with torch.no_grad()` to ignore any gradients. This speeds things up and gives the GPU's memory a rest, since we're not interesting in any kind of training from here on in.

# %%
model.eval();

# %% [markdown]
# ### Test metrics

# %%
all_efficiencies, all_purities = [], []
all_radius = np.arange(0.5, 1.2, 0.1)

with torch.no_grad():
    for r in all_radius:

        model.hparams.r_test = r
        test_results = trainer.test(ckpt_path=None)[0]

        mean_efficiency, mean_purity = test_results["eff"], test_results["pur"]

        all_efficiencies.append(mean_efficiency)
        all_purities.append(mean_purity)

# %% [markdown]
# We should always visualise two important metrics: the efficiency (the number of true positives divided by the total number of possible true edges) and the purity (the number of true positives divided by the number of predicted edges). Is it clear to you why the graphs below behave as they do, as we widen the sphere around each hit to generate neighboring edges?

# %%
plt.figure(figsize=(12,8))
plt.plot(all_radius, all_efficiencies);
plt.title("Embedding efficiency", fontsize=24), plt.xlabel("Radius of neighborhood", fontsize=18), plt.ylabel("Efficiency", fontsize=18);

# %%
plt.figure(figsize=(12,8))
plt.plot(all_radius, all_purities);
plt.title("Embedding purity", fontsize=24), plt.xlabel("Radius of neighborhood", fontsize=18), plt.ylabel("Purity", fontsize=18);

# %% [markdown]
# ### Visualise embedding / latent space

# %% [markdown]
# Another useful thing to visualise is the actual space being embedded into. Since it's 8 dimensional, we can reduce it to 2 dimensions with "Principal Component Analysis".

# %%
from sklearn.decomposition import PCA

# %%
example_data = trainset[0]
particle_ids = example_data.pid
cyl_coords = example_data.x
cell_features = example_data.cell_data
all_features = torch.cat([cyl_coords, cell_features], axis=-1).to("cuda")

# %%
latent_features = model(all_features)

# %%
pca = PCA(n_components=2)

# %%
reduced_dimensions = pca.fit_transform(latent_features.detach().cpu())

# %%
reduced_dimensions

# %%
plt.figure(figsize=(12,8))
plt.scatter(reduced_dimensions[:, 0], reduced_dimensions[:, 1], s=1)

# %% [markdown]
# The above plot is what **all** the data looks like in the latent space. Let's pick a (long) particle track and see if the track is projected to be close together:

# %%
particles, counts = np.unique(example_data.pid, return_counts=True)

# %%
example_particle = particles[counts > 10][0]

# %%
plt.figure(figsize=(12,8))
plt.scatter(reduced_dimensions[:, 0], reduced_dimensions[:, 1], s=1)
plt.scatter(reduced_dimensions[particle_ids == example_particle, 0], reduced_dimensions[particle_ids == example_particle, 1])

# %% [markdown]
# There are at least 10 hits in the plot above. Hopefully some of them cluster together into blobs, and that the blobs are close to other blobs of the same color. We get ~99% efficiency with this model, so even if some blobs appear far away in the PCA-reduced 2D space, they are most likely much closer in the 8-dimensional space. You can check this yourself!

# %% [markdown]
# ### Distributions

# %%
def calc_eta(r, z):
    theta = np.arctan2(r, z)
    return -1. * np.log(np.tan(theta / 2.))

# %%
def get_performance(model, batch, r_max, k_max):
    with torch.no_grad():
        input_data = torch.cat([batch.cell_data[:, :model.hparams["cell_channels"]], batch.x], axis=-1)
        input_data[input_data != input_data] = 0
        spatial = model(input_data)
        e_bidir = torch.cat(
                [batch.modulewise_true_edges, batch.modulewise_true_edges.flip(0)], axis=-1
            )
        e_spatial = build_edges(spatial, spatial, indices=None, r_max=r_max, k_max=k_max)
        e_spatial, y_cluster = graph_intersection(e_spatial, e_bidir)
    
    return y_cluster, e_spatial, e_bidir

# %%
r_max = 1.6
k_max = 1100

# %%
# %%time
batch = 0
model.eval()

y_cluster, e_spatial, e_bidir = get_performance(model, model.testset[batch].to(device), r_max=r_max, k_max=k_max)

# %%
print(f"Pur: {y_cluster.sum() / y_cluster.shape[0]}, Eff: {y_cluster.sum() / e_bidir.shape[1]}")

# %%
print(f"Pur: {y_cluster.sum() / y_cluster.shape[0]}, Eff: {y_cluster.sum() / e_bidir.shape[1]}")

# %%
torch.cuda.max_memory_allocated() / 1024**3

# %%
torch.cuda.reset_peak_memory_stats()

# %%
eta_cuts = np.arange(-4, 4.5, 0.5)
batch_range = np.arange(0,200)

eta_eff_list = []
eta_pur_list = []

for batch_idx in batch_range[:5]:
    
    batch = model.testset[batch_idx].to(device)
    
    y_cluster, e_spatial, e_bidir = get_performance(model, batch, r_max=r_max, k_max=k_max)
    
    eta_hits = calc_eta(batch.x[:, 0].cpu(), batch.x[:, 2].cpu())
    av_eta_preds = (eta_hits[e_spatial[0]] + eta_hits[e_spatial[1]])/2
    av_eta_true = (eta_hits[e_bidir[0]] + eta_hits[e_bidir[1]])/2
    
    for eta1, eta2 in zip(eta_cuts[:-1], eta_cuts[1:]):
        edge_eta_pred = (av_eta_preds >= eta1) & (av_eta_preds <= eta2)
        edge_eta_true = (av_eta_true >= eta1) & (av_eta_true <= eta2)
        true_positives = y_cluster[edge_eta_pred]

        eta_eff_list.append(true_positives.sum().item() / edge_eta_true.sum().item())
        eta_pur_list.append(true_positives.sum().item() / true_positives.shape[0])

# %%
eta_eff_reshape = np.array(eta_eff_list).reshape(eta_cuts.shape[0]-1, len(batch_range))
eta_pur_reshape = np.array(eta_pur_list).reshape(eta_cuts.shape[0]-1, len(batch_range))

# %% [markdown]
# Train set

# %%
plt.scatter(eta_eff_reshape.mean(0), eta_pur_reshape.mean(0), s=2)

# %% [markdown]
# Test set

# %%
plt.scatter(eta_eff_reshape.mean(0), eta_pur_reshape.mean(0), s=2)

# %%
eta_center = (eta_cuts[:-1] + eta_cuts[1:])/2
plt.errorbar(eta_center, eta_eff_reshape.mean(1), eta_eff_reshape.std(1), fmt="o")

# %%
eta_center = (eta_cuts[:-1] + eta_cuts[1:])/2
plt.errorbar(eta_center, eta_pur_reshape.mean(1), eta_pur_reshape.std(1), fmt="o")

# %%
pt_cuts = np.arange(900, 5000, 500)

pt_eff_list = []
pt_pur_list = []
    
for batch_idx in batch_range:
    
    batch = model.testset[batch_idx].to(device)
    
    y_cluster, e_spatial, e_bidir = get_performance(model, batch, r_max=1.2, k_max=500)
    
    av_pt_preds = (batch.pt[e_spatial[0]] + batch.pt[e_spatial[1]])/2
    av_pt_true = (batch.pt[e_bidir[0]] + batch.pt[e_bidir[1]])/2
    
    for pt1, pt2 in zip(pt_cuts[:-1], pt_cuts[1:]):
        edge_pt_pred = (av_pt_preds >= pt1) & (av_pt_preds <= pt2)
        edge_pt_true = (av_pt_true >= pt1) & (av_pt_true <= pt2)
        true_positives = y_cluster[edge_pt_pred]

        pt_eff_list.append(true_positives.sum().item() / max(1, edge_pt_true.sum().item()))
        pt_pur_list.append(true_positives.sum().item() / max(1, true_positives.shape[0]))

# %%
pt_eff_reshape = np.array(pt_eff_list).reshape(pt_cuts.shape[0]-1, len(batch_range))
pt_pur_reshape = np.array(pt_pur_list).reshape(pt_cuts.shape[0]-1, len(batch_range))

# %%
pt_center = (pt_cuts[:-1] + pt_cuts[1:])/2
plt.errorbar(pt_center, pt_eff_reshape.mean(1), pt_eff_reshape.std(1), fmt="o")

# %%
pt_center = (pt_cuts[:-1] + pt_cuts[1:])/2
plt.errorbar(pt_center, pt_pur_reshape.mean(1), pt_pur_reshape.std(1), fmt="o")

# %% [markdown]
# ## Memory of Edge Builder

# %%
torch.cuda.max_memory_allocated() / 1024**3

# %%
torch.cuda.reset_peak_memory_stats()

# %%
r_max = 1.6
k_max = 1000

# %%
batch = model.testset[0].to(device)
model.eval()
with torch.no_grad():
    input_data = torch.cat([batch.cell_data[:, :model.hparams["cell_channels"]], batch.x], axis=-1)
    input_data[input_data != input_data] = 0
    spatial = model(input_data)
    e_bidir = torch.cat(
            [batch.modulewise_true_edges, batch.modulewise_true_edges.flip(0)], axis=-1
        )

# %%
dists, idxs, nn, grid = frnn.frnn_grid_points(points1=spatial.unsqueeze(0), points2=spatial.unsqueeze(0), lengths1=None, lengths2=None, K=k_max, r=r_max, grid=None, return_nn=False, return_sorted=True)

# %%
idxs = idxs.squeeze().int()
ind = torch.Tensor.repeat(torch.arange(idxs.shape[0], device=device), (idxs.shape[1], 1), 1).T.int()

# %%
positive_idxs = idxs >= 0
ind = ind[positive_idxs]
idxs = idxs[positive_idxs]

# %%
edge_list = torch.stack([ind, idxs]).int()

# %%
# Remove self-loops
edge_list = edge_list[:, edge_list[0] != edge_list[1]]

# %%
del ind
del idxs

# %%
edge_list = edge_list.long()

# %% [markdown]
# # Build Edge Dataset

# %% [markdown]
# ## Load best model

# %%
checkpoint_path = "/global/cscratch1/sd/danieltm/ExaTrkX/itk_lightning_checkpoints/ITk_1GeV/pdwlz89x/checkpoints/last.ckpt"
checkpoint = torch.load(checkpoint_path)

# %%
model = LayerlessEmbedding.load_from_checkpoint(checkpoint_path).to(device)

# %%
model.hparams["train_split"] = [10, 10, 10]

# %%
# %%time
model.setup(stage="fit")

# %% [markdown]
# ## Define Building Class

# %%
class EmbeddingInferenceBuilder:
    def __init__(self, model, output_dir, overwrite=False):
        self.output_dir = output_dir
        self.model = model
        self.overwrite = overwrite

        # Prep the directory to produce inference data to
        self.datatypes = ["train", "val", "test"]
        os.makedirs(self.output_dir, exist_ok=True)
        [
            os.makedirs(os.path.join(self.output_dir, datatype), exist_ok=True)
            for datatype in self.datatypes
        ]


    def build(self):
        print("Training finished, running inference to build graphs...")

        # By default, the set of examples propagated through the pipeline will be train+val+test set
        datasets = {
            "train": self.model.trainset,
            "val": self.model.valset,
            "test": self.model.testset,
        }
        total_length = sum([len(dataset) for dataset in datasets.values()])
        batch_incr = 0
        self.model.eval()
        with torch.no_grad():
            for set_idx, (datatype, dataset) in enumerate(datasets.items()):
                for batch_idx, batch in enumerate(dataset):
                    percent = (batch_incr / total_length) * 100
                    sys.stdout.flush()
                    sys.stdout.write(f"{percent:.01f}% inference complete \r")
                    if (
                        not os.path.exists(
                            os.path.join(
                                self.output_dir, datatype, batch.event_file[-4:]
                            )
                        )
                    ) or self.overwrite:
                        batch_to_save = copy.deepcopy(batch)
                        batch_to_save = batch_to_save.to(
                            self.model.device
                        )  # Is this step necessary??
                        self.construct_downstream(batch_to_save, datatype)

                    batch_incr += 1

    def construct_downstream(self, batch, datatype):

        if "ci" in self.model.hparams["regime"]:
            input_data = torch.cat([batch.cell_data[:, :self.model.hparams["cell_channels"]], batch.x], axis=-1)
            input_data[input_data != input_data] = 0
            spatial = self.model(input_data)
        else:
            input_data = batch.x
            input_data[input_data != input_data] = 0
            spatial = self.model(input_data)

        # Make truth bidirectional
        e_bidir = torch.cat(
            [
                batch.modulewise_true_edges,
                torch.stack(
                    [batch.modulewise_true_edges[1], batch.modulewise_true_edges[0]],
                    axis=1,
                ).T,
            ],
            axis=-1,
        )

        # Build the radius graph with radius < r_test
        e_spatial = build_edges(
            spatial, spatial, indices=None, r_max=self.model.hparams["r_test"], k_max =1100
        ).long()  # This step should remove reliance on r_val, and instead compute an r_build based on the EXACT r required to reach target eff/pur

        # Arbitrary ordering to remove half of the duplicate edges
        R_dist = torch.sqrt(batch.x[:, 0] ** 2 + batch.x[:, 2] ** 2)
        e_spatial = e_spatial[:, (R_dist[e_spatial[0]] <= R_dist[e_spatial[1]])]

        e_spatial, y_cluster = graph_intersection(e_spatial, e_bidir)

        # Re-introduce random direction, to avoid training bias
        random_flip = torch.randint(2, (e_spatial.shape[1],)).bool()
        e_spatial[0, random_flip], e_spatial[1, random_flip] = (
            e_spatial[1, random_flip],
            e_spatial[0, random_flip],
        )

        batch.edge_index = e_spatial
        batch.y = y_cluster

        self.save_downstream(batch, datatype)

    def save_downstream(self, batch, datatype):

        with open(
            os.path.join(self.output_dir, datatype, batch.event_file[-4:]), "wb"
        ) as pickle_file:
            torch.save(batch, pickle_file)

# %%
output_dir = "/project/projectdirs/m3443/data/ITk-upgrade/processed/embedding_processed/0_GeV_unweighted_subset"
model.hparams["r_test"] = 1.6
edge_builder = EmbeddingInferenceBuilder(model, output_dir, overwrite=False)

# %%
edge_builder.build()

# %%
len(model.trainset)
